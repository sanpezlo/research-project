# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install transformers
# !pip install -U gensim
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)
# Requirement already satisfied: gensim in /usr/local/lib/python3.12/dist-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.4.4)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.0.0)

# %%
import tensorflow as tf
import numpy as np
import random
import os

SEED = 2025

os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
tf.config.experimental.enable_op_determinism()

# %%
import tensorflow as tf

print("GPU available:", tf.config.list_physical_devices('GPU'))

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        print(e)
# Out:
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 1 Physical GPUs, 1 Logical GPUs

# %%
import tensorflow as tf

dataset_train = tf.data.Dataset.load("/content/drive/MyDrive/Universidad/Investigacion/tf_datasets/train")

# %%
from tensorflow.keras.layers import Dense, Input, Dropout, Bidirectional, LSTM, Embedding, BatchNormalization, Reshape, Conv2D, MaxPool2D, concatenate, Flatten
from tensorflow.keras.layers import Conv1D, GlobalMaxPooling1D, MaxPooling1D, Input, Bidirectional, GRU, Flatten, concatenate, BatchNormalization, Dense, LeakyReLU, Activation
from tensorflow.keras.models import Model
from keras import regularizers

num_classes = 8

def create_input_branch(input_shape, name):
    input_layer = Input(shape=input_shape, name=name)
    dense1 = Dense(10000)(input_layer)
    batch1 = BatchNormalization()(dense1)
    activation1 = Activation('relu')(batch1)
    drop1 = Dropout(0.2)(activation1)

    dense2 = Dense(1000)(drop1)
    batch2 = BatchNormalization()(dense2)
    activation2 = Activation('relu')(batch2)
    drop2 = Dropout(0.2)(activation2)

    dense3 = Dense(100)(drop2)
    batch3 = BatchNormalization()(dense3)
    activation3 = Activation('relu')(batch3)
    drop3 = Dropout(0.2)(activation3)

    dense4 = Dense(10)(drop3)
    batch4 = BatchNormalization()(dense4)
    activation4 = Activation('relu')(batch4)
    drop4 = Dropout(0.2)(activation4)
    return input_layer, drop4

input_nl, output_nl = create_input_branch((768,), "nl")
input_pl, output_pl = create_input_branch((768,), "pl")
input_initial, output_initial = create_input_branch((768,), "initial")
input_transformation, output_transformation = create_input_branch((768,), "transformation")
input_js, output_js = create_input_branch((768,), "js")
input_final, output_final = create_input_branch((768,), "final")


concat = concatenate([output_nl, output_pl, output_initial, output_transformation, output_js, output_final])

output = Dense(num_classes)(concat)
output = BatchNormalization()(output)
output = Activation('softmax')(output)

model = Model(inputs=[input_nl, input_pl, input_initial, input_transformation, input_js, input_final], outputs=output)

# %%
# %%time
from tensorflow.keras.optimizers import Adam
adam = Adam(learning_rate=0.00001)

model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy', tf.keras.metrics.F1Score(average='macro')])

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ nl (InputLayer)     │ (None, 768)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pl (InputLayer)     │ (None, 768)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ initial             │ (None, 768)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformation      │ (None, 768)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ js (InputLayer)     │ (None, 768)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final (InputLayer)  │ (None, 768)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 10000)     │  7,690,000 │ nl[0][0]          │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 10000)     │  7,690,000 │ pl[0][0]          │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 10000)     │  7,690,000 │ initial[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 10000)     │  7,690,000 │ transformation[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 10000)     │  7,690,000 │ js[0][0]          │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 10000)     │  7,690,000 │ final[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 10000)     │     40,000 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_4[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_8[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_12[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_16[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_20[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 10000)     │          0 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 10000)     │          0 │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 10000)     │          0 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 10000)     │          0 │ activation_12[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 10000)     │          0 │ activation_16[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 10000)     │          0 │ activation_20[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1000)      │ 10,001,000 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 1000)      │ 10,001,000 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 1000)      │ 10,001,000 │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 1000)      │ 10,001,000 │ dropout_12[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 1000)      │ 10,001,000 │ dropout_16[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_21 (Dense)    │ (None, 1000)      │ 10,001,000 │ dropout_20[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1000)      │      4,000 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1000)      │      4,000 │ dense_5[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1000)      │      4,000 │ dense_9[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1000)      │      4,000 │ dense_13[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1000)      │      4,000 │ dense_17[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1000)      │      4,000 │ dense_21[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 1000)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 1000)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 1000)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 1000)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 1000)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 1000)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 1000)      │          0 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 1000)      │          0 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 1000)      │          0 │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 1000)      │          0 │ activation_13[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 1000)      │          0 │ activation_17[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_21          │ (None, 1000)      │          0 │ activation_21[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 100)       │    100,100 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 100)       │    100,100 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 100)       │    100,100 │ dropout_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 100)       │    100,100 │ dropout_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 100)       │    100,100 │ dropout_17[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_22 (Dense)    │ (None, 100)       │    100,100 │ dropout_21[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100)       │        400 │ dense_2[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100)       │        400 │ dense_6[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100)       │        400 │ dense_10[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100)       │        400 │ dense_14[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100)       │        400 │ dense_18[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100)       │        400 │ dense_22[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 100)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 100)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 100)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 100)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 100)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 100)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 100)       │          0 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 100)       │          0 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 100)       │          0 │ activation_10[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 100)       │          0 │ activation_14[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_18          │ (None, 100)       │          0 │ activation_18[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 100)       │          0 │ activation_22[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 10)        │      1,010 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 10)        │      1,010 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 10)        │      1,010 │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 10)        │      1,010 │ dropout_14[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 10)        │      1,010 │ dropout_18[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_23 (Dense)    │ (None, 10)        │      1,010 │ dropout_22[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10)        │         40 │ dense_3[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10)        │         40 │ dense_7[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10)        │         40 │ dense_11[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10)        │         40 │ dense_15[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10)        │         40 │ dense_19[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10)        │         40 │ dense_23[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 10)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 10)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 10)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 10)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 10)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 10)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 10)        │          0 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 10)        │          0 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 10)        │          0 │ activation_11[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, 10)        │          0 │ activation_15[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 10)        │          0 │ activation_19[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 10)        │          0 │ activation_23[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 60)        │          0 │ dropout_3[0][0],  │
# │ (Concatenate)       │                   │            │ dropout_7[0][0],  │
# │                     │                   │            │ dropout_11[0][0], │
# │                     │                   │            │ dropout_15[0][0], │
# │                     │                   │            │ dropout_19[0][0], │
# │                     │                   │            │ dropout_23[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_24 (Dense)    │ (None, 8)         │        488 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8)         │         32 │ dense_24[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 8)         │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 107,019,820 (408.25 MB)
#  Trainable params: 106,886,484 (407.74 MB)
#  Non-trainable params: 133,336 (520.84 KB)
# CPU times: user 96.4 ms, sys: 3 ms, total: 99.4 ms
# Wall time: 98.2 ms

# %%
from tensorflow.keras.callbacks import EarlyStopping

total_size = dataset_train.reduce(0, lambda x, _: x + 1).numpy()
val_size = int(0.2 * total_size)

dataset_train = dataset_train.shuffle(
    buffer_size=total_size,
    seed=SEED,
    reshuffle_each_iteration=False
)

val_dataset = dataset_train.take(val_size)
train_dataset = dataset_train.skip(val_size)



epochs=150

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)


history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=epochs,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 114s 93ms/step - accuracy: 0.2230 - f1_score: 0.2219 - loss: 2.0365 - val_accuracy: 0.4286 - val_f1_score: 0.4169 - val_loss: 1.5845
# Epoch 2/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.3414 - f1_score: 0.3390 - loss: 1.7140 - val_accuracy: 0.4900 - val_f1_score: 0.4829 - val_loss: 1.4512
# Epoch 3/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.4028 - f1_score: 0.4000 - loss: 1.5824 - val_accuracy: 0.5557 - val_f1_score: 0.5477 - val_loss: 1.3634
# Epoch 4/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.4500 - f1_score: 0.4469 - loss: 1.4907 - val_accuracy: 0.6359 - val_f1_score: 0.6299 - val_loss: 1.2809
# Epoch 5/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 93ms/step - accuracy: 0.5041 - f1_score: 0.5001 - loss: 1.4128 - val_accuracy: 0.6559 - val_f1_score: 0.6500 - val_loss: 1.2228
# Epoch 6/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.5343 - f1_score: 0.5306 - loss: 1.3561 - val_accuracy: 0.7166 - val_f1_score: 0.7122 - val_loss: 1.1520
# Epoch 7/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.5743 - f1_score: 0.5711 - loss: 1.3014 - val_accuracy: 0.7384 - val_f1_score: 0.7348 - val_loss: 1.1446
# Epoch 8/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.6016 - f1_score: 0.5986 - loss: 1.2562 - val_accuracy: 0.7625 - val_f1_score: 0.7589 - val_loss: 1.0971
# Epoch 9/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.6274 - f1_score: 0.6246 - loss: 1.2131 - val_accuracy: 0.7504 - val_f1_score: 0.7476 - val_loss: 1.0819
# Epoch 10/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.6578 - f1_score: 0.6553 - loss: 1.1776 - val_accuracy: 0.8050 - val_f1_score: 0.8025 - val_loss: 1.0252
# Epoch 11/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.6767 - f1_score: 0.6741 - loss: 1.1395 - val_accuracy: 0.7575 - val_f1_score: 0.7561 - val_loss: 1.0432
# Epoch 12/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 93ms/step - accuracy: 0.6984 - f1_score: 0.6962 - loss: 1.1094 - val_accuracy: 0.8069 - val_f1_score: 0.8057 - val_loss: 0.9904
# Epoch 13/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 93ms/step - accuracy: 0.7127 - f1_score: 0.7109 - loss: 1.0862 - val_accuracy: 0.8190 - val_f1_score: 0.8169 - val_loss: 0.9797
# Epoch 14/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.7286 - f1_score: 0.7271 - loss: 1.0568 - val_accuracy: 0.8405 - val_f1_score: 0.8392 - val_loss: 0.9578
# Epoch 15/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.7414 - f1_score: 0.7399 - loss: 1.0330 - val_accuracy: 0.8368 - val_f1_score: 0.8356 - val_loss: 0.9310
# Epoch 16/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.7559 - f1_score: 0.7544 - loss: 1.0142 - val_accuracy: 0.8116 - val_f1_score: 0.8106 - val_loss: 0.9506
# Epoch 17/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.7698 - f1_score: 0.7688 - loss: 0.9854 - val_accuracy: 0.8454 - val_f1_score: 0.8439 - val_loss: 0.8672
# Epoch 18/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 93ms/step - accuracy: 0.7794 - f1_score: 0.7780 - loss: 0.9681 - val_accuracy: 0.8594 - val_f1_score: 0.8588 - val_loss: 0.8594
# Epoch 19/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 93ms/step - accuracy: 0.7904 - f1_score: 0.7899 - loss: 0.9474 - val_accuracy: 0.8505 - val_f1_score: 0.8491 - val_loss: 0.8627
# Epoch 20/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 93ms/step - accuracy: 0.7939 - f1_score: 0.7930 - loss: 0.9368 - val_accuracy: 0.8611 - val_f1_score: 0.8597 - val_loss: 0.8135
# Epoch 21/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 93ms/step - accuracy: 0.8057 - f1_score: 0.8050 - loss: 0.9180 - val_accuracy: 0.8728 - val_f1_score: 0.8725 - val_loss: 0.7986
# Epoch 22/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.8146 - f1_score: 0.8140 - loss: 0.8961 - val_accuracy: 0.8720 - val_f1_score: 0.8707 - val_loss: 0.8002
# Epoch 23/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.8136 - f1_score: 0.8129 - loss: 0.8888 - val_accuracy: 0.8587 - val_f1_score: 0.8587 - val_loss: 0.8265
# Epoch 24/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 93ms/step - accuracy: 0.8265 - f1_score: 0.8259 - loss: 0.8670 - val_accuracy: 0.8518 - val_f1_score: 0.8506 - val_loss: 0.7876
# Epoch 25/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 93ms/step - accuracy: 0.8309 - f1_score: 0.8304 - loss: 0.8534 - val_accuracy: 0.8157 - val_f1_score: 0.8142 - val_loss: 0.8431
# Epoch 26/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 93ms/step - accuracy: 0.8337 - f1_score: 0.8332 - loss: 0.8425 - val_accuracy: 0.8770 - val_f1_score: 0.8760 - val_loss: 0.7409
# Epoch 27/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 92ms/step - accuracy: 0.8429 - f1_score: 0.8424 - loss: 0.8270 - val_accuracy: 0.8730 - val_f1_score: 0.8725 - val_loss: 0.7277
# Epoch 28/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.8455 - f1_score: 0.8449 - loss: 0.8118 - val_accuracy: 0.8655 - val_f1_score: 0.8646 - val_loss: 0.7580
# Epoch 29/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 93ms/step - accuracy: 0.8455 - f1_score: 0.8451 - loss: 0.8027 - val_accuracy: 0.8809 - val_f1_score: 0.8803 - val_loss: 0.6850
# Epoch 30/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.8500 - f1_score: 0.8495 - loss: 0.7882 - val_accuracy: 0.8387 - val_f1_score: 0.8360 - val_loss: 0.7315
# Epoch 31/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 92ms/step - accuracy: 0.8569 - f1_score: 0.8565 - loss: 0.7728 - val_accuracy: 0.8894 - val_f1_score: 0.8888 - val_loss: 0.6710
# Epoch 32/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.8575 - f1_score: 0.8572 - loss: 0.7642 - val_accuracy: 0.8660 - val_f1_score: 0.8648 - val_loss: 0.6715
# Epoch 33/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.8619 - f1_score: 0.8615 - loss: 0.7546 - val_accuracy: 0.8808 - val_f1_score: 0.8798 - val_loss: 0.6583
# Epoch 34/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.8645 - f1_score: 0.8642 - loss: 0.7417 - val_accuracy: 0.8778 - val_f1_score: 0.8776 - val_loss: 0.7078
# Epoch 35/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.8670 - f1_score: 0.8667 - loss: 0.7328 - val_accuracy: 0.8659 - val_f1_score: 0.8644 - val_loss: 0.6690
# Epoch 36/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.8695 - f1_score: 0.8691 - loss: 0.7210 - val_accuracy: 0.8563 - val_f1_score: 0.8544 - val_loss: 0.6623
# Epoch 37/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.8730 - f1_score: 0.8726 - loss: 0.7072 - val_accuracy: 0.8813 - val_f1_score: 0.8800 - val_loss: 0.6325
# Epoch 38/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.8801 - f1_score: 0.8799 - loss: 0.6967 - val_accuracy: 0.8267 - val_f1_score: 0.8256 - val_loss: 0.7556
# Epoch 39/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.8766 - f1_score: 0.8762 - loss: 0.6876 - val_accuracy: 0.8937 - val_f1_score: 0.8934 - val_loss: 0.6372
# Epoch 40/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 93ms/step - accuracy: 0.8799 - f1_score: 0.8796 - loss: 0.6774 - val_accuracy: 0.8755 - val_f1_score: 0.8746 - val_loss: 0.6305
# Epoch 41/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 92ms/step - accuracy: 0.8837 - f1_score: 0.8833 - loss: 0.6682 - val_accuracy: 0.8851 - val_f1_score: 0.8847 - val_loss: 0.6988
# Epoch 42/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 93ms/step - accuracy: 0.8838 - f1_score: 0.8834 - loss: 0.6610 - val_accuracy: 0.8990 - val_f1_score: 0.8984 - val_loss: 0.6066
# Epoch 43/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 92ms/step - accuracy: 0.8904 - f1_score: 0.8901 - loss: 0.6476 - val_accuracy: 0.8780 - val_f1_score: 0.8773 - val_loss: 0.5850
# Epoch 44/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.8889 - f1_score: 0.8885 - loss: 0.6415 - val_accuracy: 0.8980 - val_f1_score: 0.8977 - val_loss: 0.6588
# Epoch 45/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 92ms/step - accuracy: 0.8911 - f1_score: 0.8908 - loss: 0.6332 - val_accuracy: 0.9197 - val_f1_score: 0.9195 - val_loss: 0.5590
# Epoch 46/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 92ms/step - accuracy: 0.8949 - f1_score: 0.8946 - loss: 0.6198 - val_accuracy: 0.8540 - val_f1_score: 0.8530 - val_loss: 0.6033
# Epoch 47/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.8936 - f1_score: 0.8933 - loss: 0.6139 - val_accuracy: 0.8794 - val_f1_score: 0.8794 - val_loss: 0.5844
# Epoch 48/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 92ms/step - accuracy: 0.8971 - f1_score: 0.8968 - loss: 0.6055 - val_accuracy: 0.8694 - val_f1_score: 0.8676 - val_loss: 0.5519
# Epoch 49/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 92ms/step - accuracy: 0.8989 - f1_score: 0.8987 - loss: 0.5977 - val_accuracy: 0.9006 - val_f1_score: 0.8999 - val_loss: 0.5312
# Epoch 50/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9022 - f1_score: 0.9021 - loss: 0.5883 - val_accuracy: 0.8618 - val_f1_score: 0.8614 - val_loss: 0.6287
# Epoch 51/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9017 - f1_score: 0.9015 - loss: 0.5817 - val_accuracy: 0.9107 - val_f1_score: 0.9102 - val_loss: 0.5337
# Epoch 52/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 93ms/step - accuracy: 0.8969 - f1_score: 0.8967 - loss: 0.5756 - val_accuracy: 0.8812 - val_f1_score: 0.8813 - val_loss: 0.5916
# Epoch 53/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 92ms/step - accuracy: 0.9022 - f1_score: 0.9020 - loss: 0.5695 - val_accuracy: 0.8413 - val_f1_score: 0.8389 - val_loss: 0.6039
# Epoch 54/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9066 - f1_score: 0.9064 - loss: 0.5562 - val_accuracy: 0.8820 - val_f1_score: 0.8802 - val_loss: 0.5355
# Epoch 55/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9061 - f1_score: 0.9060 - loss: 0.5515 - val_accuracy: 0.8219 - val_f1_score: 0.8179 - val_loss: 0.6528
# Epoch 56/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9083 - f1_score: 0.9081 - loss: 0.5448 - val_accuracy: 0.8181 - val_f1_score: 0.8217 - val_loss: 0.6503
# Epoch 57/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9083 - f1_score: 0.9081 - loss: 0.5366 - val_accuracy: 0.8687 - val_f1_score: 0.8688 - val_loss: 0.5544
# Epoch 58/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9105 - f1_score: 0.9103 - loss: 0.5310 - val_accuracy: 0.8675 - val_f1_score: 0.8669 - val_loss: 0.5998
# Epoch 59/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9117 - f1_score: 0.9115 - loss: 0.5244 - val_accuracy: 0.8817 - val_f1_score: 0.8810 - val_loss: 0.5268
# Epoch 60/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 92ms/step - accuracy: 0.9135 - f1_score: 0.9133 - loss: 0.5194 - val_accuracy: 0.8964 - val_f1_score: 0.8955 - val_loss: 0.4888
# Epoch 61/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9133 - f1_score: 0.9131 - loss: 0.5146 - val_accuracy: 0.8783 - val_f1_score: 0.8785 - val_loss: 0.5134
# Epoch 62/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9180 - f1_score: 0.9178 - loss: 0.5033 - val_accuracy: 0.8935 - val_f1_score: 0.8931 - val_loss: 0.4568
# Epoch 63/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9168 - f1_score: 0.9167 - loss: 0.5001 - val_accuracy: 0.9090 - val_f1_score: 0.9083 - val_loss: 0.4749
# Epoch 64/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9188 - f1_score: 0.9185 - loss: 0.4923 - val_accuracy: 0.8434 - val_f1_score: 0.8417 - val_loss: 0.5753
# Epoch 65/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 93ms/step - accuracy: 0.9195 - f1_score: 0.9192 - loss: 0.4883 - val_accuracy: 0.8381 - val_f1_score: 0.8386 - val_loss: 0.5918
# Epoch 66/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 92ms/step - accuracy: 0.9178 - f1_score: 0.9176 - loss: 0.4826 - val_accuracy: 0.8865 - val_f1_score: 0.8867 - val_loss: 0.4913
# Epoch 67/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9179 - f1_score: 0.9177 - loss: 0.4787 - val_accuracy: 0.8730 - val_f1_score: 0.8719 - val_loss: 0.4942
# Epoch 68/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9230 - f1_score: 0.9228 - loss: 0.4689 - val_accuracy: 0.8226 - val_f1_score: 0.8173 - val_loss: 0.6362
# Epoch 69/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9240 - f1_score: 0.9238 - loss: 0.4648 - val_accuracy: 0.8880 - val_f1_score: 0.8873 - val_loss: 0.4615
# Epoch 70/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 92ms/step - accuracy: 0.9258 - f1_score: 0.9256 - loss: 0.4579 - val_accuracy: 0.8087 - val_f1_score: 0.8023 - val_loss: 0.6201
# Epoch 71/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 93ms/step - accuracy: 0.9252 - f1_score: 0.9250 - loss: 0.4550 - val_accuracy: 0.9089 - val_f1_score: 0.9082 - val_loss: 0.4298
# Epoch 72/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 93ms/step - accuracy: 0.9242 - f1_score: 0.9240 - loss: 0.4535 - val_accuracy: 0.8823 - val_f1_score: 0.8824 - val_loss: 0.4932
# Epoch 73/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 93ms/step - accuracy: 0.9288 - f1_score: 0.9287 - loss: 0.4452 - val_accuracy: 0.8648 - val_f1_score: 0.8635 - val_loss: 0.5219
# Epoch 74/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 93ms/step - accuracy: 0.9288 - f1_score: 0.9285 - loss: 0.4396 - val_accuracy: 0.8365 - val_f1_score: 0.8341 - val_loss: 0.5725
# Epoch 75/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 93ms/step - accuracy: 0.9320 - f1_score: 0.9318 - loss: 0.4329 - val_accuracy: 0.8855 - val_f1_score: 0.8843 - val_loss: 0.4555
# Epoch 76/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 93ms/step - accuracy: 0.9289 - f1_score: 0.9286 - loss: 0.4343 - val_accuracy: 0.9222 - val_f1_score: 0.9220 - val_loss: 0.4172
# Epoch 77/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9297 - f1_score: 0.9295 - loss: 0.4270 - val_accuracy: 0.8426 - val_f1_score: 0.8420 - val_loss: 0.5598
# Epoch 78/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9333 - f1_score: 0.9331 - loss: 0.4222 - val_accuracy: 0.8601 - val_f1_score: 0.8597 - val_loss: 0.5346
# Epoch 79/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9332 - f1_score: 0.9329 - loss: 0.4195 - val_accuracy: 0.8971 - val_f1_score: 0.8975 - val_loss: 0.4448
# Epoch 80/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9355 - f1_score: 0.9354 - loss: 0.4102 - val_accuracy: 0.8455 - val_f1_score: 0.8478 - val_loss: 0.5613
# Epoch 81/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9403 - f1_score: 0.9401 - loss: 0.4034 - val_accuracy: 0.8534 - val_f1_score: 0.8546 - val_loss: 0.5503
# Epoch 82/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9370 - f1_score: 0.9368 - loss: 0.4028 - val_accuracy: 0.7983 - val_f1_score: 0.7922 - val_loss: 0.6666
# Epoch 83/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9358 - f1_score: 0.9356 - loss: 0.3989 - val_accuracy: 0.8281 - val_f1_score: 0.8240 - val_loss: 0.5706
# Epoch 84/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 92ms/step - accuracy: 0.9398 - f1_score: 0.9396 - loss: 0.3893 - val_accuracy: 0.9169 - val_f1_score: 0.9169 - val_loss: 0.4138
# Epoch 85/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9385 - f1_score: 0.9382 - loss: 0.3905 - val_accuracy: 0.9154 - val_f1_score: 0.9148 - val_loss: 0.4120
# Epoch 86/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9365 - f1_score: 0.9363 - loss: 0.3895 - val_accuracy: 0.8338 - val_f1_score: 0.8314 - val_loss: 0.5779
# Epoch 87/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9395 - f1_score: 0.9393 - loss: 0.3782 - val_accuracy: 0.7706 - val_f1_score: 0.7712 - val_loss: 0.7042
# Epoch 88/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9414 - f1_score: 0.9412 - loss: 0.3788 - val_accuracy: 0.8392 - val_f1_score: 0.8365 - val_loss: 0.5540
# Epoch 89/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 93ms/step - accuracy: 0.9428 - f1_score: 0.9426 - loss: 0.3730 - val_accuracy: 0.9046 - val_f1_score: 0.9034 - val_loss: 0.3837
# Epoch 90/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9447 - f1_score: 0.9445 - loss: 0.3702 - val_accuracy: 0.8629 - val_f1_score: 0.8641 - val_loss: 0.4985
# Epoch 91/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9459 - f1_score: 0.9457 - loss: 0.3630 - val_accuracy: 0.8836 - val_f1_score: 0.8834 - val_loss: 0.4837
# Epoch 92/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9453 - f1_score: 0.9452 - loss: 0.3619 - val_accuracy: 0.8703 - val_f1_score: 0.8695 - val_loss: 0.4982
# Epoch 93/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9425 - f1_score: 0.9424 - loss: 0.3610 - val_accuracy: 0.8344 - val_f1_score: 0.8347 - val_loss: 0.5603
# Epoch 94/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9422 - f1_score: 0.9420 - loss: 0.3588 - val_accuracy: 0.8994 - val_f1_score: 0.8991 - val_loss: 0.3884
# Epoch 95/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9483 - f1_score: 0.9481 - loss: 0.3492 - val_accuracy: 0.8931 - val_f1_score: 0.8925 - val_loss: 0.4495
# Epoch 96/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9489 - f1_score: 0.9487 - loss: 0.3457 - val_accuracy: 0.8183 - val_f1_score: 0.8197 - val_loss: 0.5919
# Epoch 97/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9467 - f1_score: 0.9465 - loss: 0.3471 - val_accuracy: 0.8823 - val_f1_score: 0.8816 - val_loss: 0.4343
# Epoch 98/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 92s 92ms/step - accuracy: 0.9479 - f1_score: 0.9477 - loss: 0.3421 - val_accuracy: 0.8512 - val_f1_score: 0.8504 - val_loss: 0.5077
# Epoch 99/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 93s 93ms/step - accuracy: 0.9484 - f1_score: 0.9482 - loss: 0.3405 - val_accuracy: 0.8502 - val_f1_score: 0.8506 - val_loss: 0.5362
# Epoch 99: early stopping
# Restoring model weights from the end of the best epoch: 89.

# %%
model.save('/content/drive/MyDrive/Universidad/Investigacion/models/2.keras')

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
train_f1 = history.history['f1_score']
val_f1 = history.history['val_f1_score']

# %%
length = len(history.history['accuracy'])

# %%
import matplotlib.pyplot as plt

plt.plot(range(1, length+1), train_loss, label='Train Loss')
plt.plot(range(1, length+1), val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curves')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(range(1, length+1), train_f1, label='Train F1')
plt.plot(range(1, length+1), val_f1, label='Validation F1')
plt.xlabel('Epoch')
plt.ylabel('F1')
plt.title('F1 Curves')
plt.legend()
plt.show()
