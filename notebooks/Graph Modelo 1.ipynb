# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers
# !pip install -U gensim
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.4.4)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.0.0)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 84.5 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
import tensorflow as tf
import numpy as np
import random
import os

SEED = 2025

os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
tf.config.experimental.enable_op_determinism()

# %%
import tensorflow as tf

print("GPU available:", tf.config.list_physical_devices('GPU'))

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        print(e)
# Out:
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 1 Physical GPUs, 1 Logical GPUs

# %%
import tensorflow as tf

dataset_train = tf.data.Dataset.load("/content/drive/MyDrive/Universidad/Investigacion/tf_datasets_2/train")

# %%
from tensorflow.keras.layers import Dense, Input, Dropout, Bidirectional, LSTM, Embedding, BatchNormalization, Reshape, Conv2D, MaxPool2D, concatenate, Flatten
from tensorflow.keras.layers import Conv1D, GlobalMaxPooling1D, MaxPooling1D, Input, Bidirectional, GRU, Flatten, concatenate, BatchNormalization, Dense, LeakyReLU, Activation
from tensorflow.keras.models import Model
from keras import regularizers

num_classes = 8

def create_input_branch(input_shape, name):
    input_layer = Input(shape=input_shape, name=name)
    dense1 = Dense(10000)(input_layer)
    batch1 = BatchNormalization()(dense1)
    activation1 = Activation('relu')(batch1)
    drop1 = Dropout(0.5)(activation1)

    dense2 = Dense(1000)(drop1)
    batch2 = BatchNormalization()(dense2)
    activation2 = Activation('relu')(batch2)
    drop2 = Dropout(0.2)(activation2)

    dense3 = Dense(10000)(drop2)
    batch3 = BatchNormalization()(dense3)
    activation3 = Activation('relu')(batch3)
    drop3 = Dropout(0.2)(activation3)
    return input_layer, drop3

input_nl, output_nl = create_input_branch((768,), "nl")
input_pl, output_pl = create_input_branch((768,), "pl")
input_initial, output_initial = create_input_branch((768,), "initial")
input_transformation, output_transformation = create_input_branch((768,), "transformation")
input_js, output_js = create_input_branch((768,), "js")
input_final, output_final = create_input_branch((768,), "final")


concat = concatenate([output_nl, output_pl, output_initial, output_transformation, output_js, output_final])

output = Dense(num_classes)(concat)
output = BatchNormalization()(output)
output = Activation('softmax')(output)

model = Model(inputs=[input_nl, input_pl, input_initial, input_transformation, input_js, input_final], outputs=output)

# %%
# %%time
from tensorflow.keras.optimizers import Adam
adam = Adam(learning_rate=0.00001)

model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy', tf.keras.metrics.F1Score(average='macro')])

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ nl (InputLayer)     │ (None, 768)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pl (InputLayer)     │ (None, 768)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ initial             │ (None, 768)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformation      │ (None, 768)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ js (InputLayer)     │ (None, 768)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final (InputLayer)  │ (None, 768)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 10000)     │  7,690,000 │ nl[0][0]          │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 10000)     │  7,690,000 │ pl[0][0]          │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 10000)     │  7,690,000 │ initial[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 10000)     │  7,690,000 │ transformation[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 10000)     │  7,690,000 │ js[0][0]          │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 10000)     │  7,690,000 │ final[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 10000)     │     40,000 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_3[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_6[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_9[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_12[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_15[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 10000)     │          0 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 10000)     │          0 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 10000)     │          0 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 10000)     │          0 │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 10000)     │          0 │ activation_12[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, 10000)     │          0 │ activation_15[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1000)      │ 10,001,000 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 1000)      │ 10,001,000 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 1000)      │ 10,001,000 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 1000)      │ 10,001,000 │ dropout_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 1000)      │ 10,001,000 │ dropout_12[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 1000)      │ 10,001,000 │ dropout_15[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1000)      │      4,000 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1000)      │      4,000 │ dense_4[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1000)      │      4,000 │ dense_7[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1000)      │      4,000 │ dense_10[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1000)      │      4,000 │ dense_13[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1000)      │      4,000 │ dense_16[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 1000)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 1000)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 1000)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 1000)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 1000)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 1000)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 1000)      │          0 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 1000)      │          0 │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 1000)      │          0 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 1000)      │          0 │ activation_10[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 1000)      │          0 │ activation_13[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 1000)      │          0 │ activation_16[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 10000)     │ 10,010,000 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 10000)     │ 10,010,000 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 10000)     │ 10,010,000 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 10000)     │ 10,010,000 │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 10000)     │ 10,010,000 │ dropout_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 10000)     │ 10,010,000 │ dropout_16[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_2[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_5[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_8[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_11[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_14[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_17[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 10000)     │          0 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 10000)     │          0 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 10000)     │          0 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 10000)     │          0 │ activation_11[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 10000)     │          0 │ activation_14[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 10000)     │          0 │ activation_17[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 60000)     │          0 │ dropout_2[0][0],  │
# │ (Concatenate)       │                   │            │ dropout_5[0][0],  │
# │                     │                   │            │ dropout_8[0][0],  │
# │                     │                   │            │ dropout_11[0][0], │
# │                     │                   │            │ dropout_14[0][0], │
# │                     │                   │            │ dropout_17[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 8)         │    480,008 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8)         │         32 │ dense_18[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 8)         │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 167,190,040 (637.78 MB)
#  Trainable params: 166,938,024 (636.82 MB)
#  Non-trainable params: 252,016 (984.44 KB)
# CPU times: user 97.6 ms, sys: 1.84 ms, total: 99.5 ms
# Wall time: 101 ms

# %%
from tensorflow.keras.callbacks import EarlyStopping

total_size = dataset_train.reduce(0, lambda x, _: x + 1).numpy()
val_size = int(0.2 * total_size)

dataset_train = dataset_train.shuffle(
    buffer_size=total_size,
    seed=SEED,
    reshuffle_each_iteration=False
)

val_dataset = dataset_train.take(val_size)
train_dataset = dataset_train.skip(val_size)



epochs=150

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)


history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=epochs,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 132s 117ms/step - accuracy: 0.3400 - f1_score: 0.3383 - loss: 1.7302 - val_accuracy: 0.6166 - val_f1_score: 0.6092 - val_loss: 1.1963
# Epoch 2/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.6028 - f1_score: 0.6009 - loss: 1.2630 - val_accuracy: 0.7548 - val_f1_score: 0.7507 - val_loss: 0.9911
# Epoch 3/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.7221 - f1_score: 0.7208 - loss: 1.1327 - val_accuracy: 0.8145 - val_f1_score: 0.8127 - val_loss: 0.9156
# Epoch 4/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.7786 - f1_score: 0.7775 - loss: 1.0682 - val_accuracy: 0.8469 - val_f1_score: 0.8453 - val_loss: 0.8629
# Epoch 5/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.8123 - f1_score: 0.8119 - loss: 1.0232 - val_accuracy: 0.8535 - val_f1_score: 0.8521 - val_loss: 0.8309
# Epoch 6/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.8332 - f1_score: 0.8326 - loss: 0.9870 - val_accuracy: 0.8650 - val_f1_score: 0.8637 - val_loss: 0.8011
# Epoch 7/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 116ms/step - accuracy: 0.8455 - f1_score: 0.8450 - loss: 0.9550 - val_accuracy: 0.8656 - val_f1_score: 0.8640 - val_loss: 0.7682
# Epoch 8/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.8543 - f1_score: 0.8537 - loss: 0.9241 - val_accuracy: 0.8672 - val_f1_score: 0.8657 - val_loss: 0.7417
# Epoch 9/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.8615 - f1_score: 0.8612 - loss: 0.8949 - val_accuracy: 0.8661 - val_f1_score: 0.8650 - val_loss: 0.7125
# Epoch 10/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.8661 - f1_score: 0.8656 - loss: 0.8689 - val_accuracy: 0.8759 - val_f1_score: 0.8747 - val_loss: 0.6986
# Epoch 11/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.8713 - f1_score: 0.8709 - loss: 0.8440 - val_accuracy: 0.8834 - val_f1_score: 0.8825 - val_loss: 0.6740
# Epoch 12/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.8708 - f1_score: 0.8705 - loss: 0.8221 - val_accuracy: 0.8820 - val_f1_score: 0.8809 - val_loss: 0.6469
# Epoch 13/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.8827 - f1_score: 0.8825 - loss: 0.7970 - val_accuracy: 0.8878 - val_f1_score: 0.8867 - val_loss: 0.6317
# Epoch 14/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 116ms/step - accuracy: 0.8807 - f1_score: 0.8804 - loss: 0.7790 - val_accuracy: 0.8926 - val_f1_score: 0.8918 - val_loss: 0.6145
# Epoch 15/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.8872 - f1_score: 0.8870 - loss: 0.7565 - val_accuracy: 0.8965 - val_f1_score: 0.8955 - val_loss: 0.5918
# Epoch 16/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.8900 - f1_score: 0.8897 - loss: 0.7370 - val_accuracy: 0.9028 - val_f1_score: 0.9021 - val_loss: 0.5761
# Epoch 17/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.8941 - f1_score: 0.8938 - loss: 0.7195 - val_accuracy: 0.8992 - val_f1_score: 0.8983 - val_loss: 0.5572
# Epoch 18/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.8976 - f1_score: 0.8975 - loss: 0.7012 - val_accuracy: 0.9056 - val_f1_score: 0.9048 - val_loss: 0.5389
# Epoch 19/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9018 - f1_score: 0.9017 - loss: 0.6844 - val_accuracy: 0.9162 - val_f1_score: 0.9158 - val_loss: 0.5327
# Epoch 20/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9029 - f1_score: 0.9028 - loss: 0.6652 - val_accuracy: 0.9149 - val_f1_score: 0.9143 - val_loss: 0.5250
# Epoch 21/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9061 - f1_score: 0.9060 - loss: 0.6490 - val_accuracy: 0.9145 - val_f1_score: 0.9139 - val_loss: 0.5015
# Epoch 22/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 116ms/step - accuracy: 0.9099 - f1_score: 0.9098 - loss: 0.6320 - val_accuracy: 0.9214 - val_f1_score: 0.9210 - val_loss: 0.4940
# Epoch 23/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9128 - f1_score: 0.9127 - loss: 0.6188 - val_accuracy: 0.9246 - val_f1_score: 0.9241 - val_loss: 0.4756
# Epoch 24/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9164 - f1_score: 0.9164 - loss: 0.6021 - val_accuracy: 0.9259 - val_f1_score: 0.9254 - val_loss: 0.4675
# Epoch 25/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 116s 115ms/step - accuracy: 0.9172 - f1_score: 0.9172 - loss: 0.5890 - val_accuracy: 0.9193 - val_f1_score: 0.9188 - val_loss: 0.4475
# Epoch 26/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9196 - f1_score: 0.9195 - loss: 0.5757 - val_accuracy: 0.9271 - val_f1_score: 0.9268 - val_loss: 0.4528
# Epoch 27/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9217 - f1_score: 0.9217 - loss: 0.5637 - val_accuracy: 0.9278 - val_f1_score: 0.9274 - val_loss: 0.4432
# Epoch 28/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9245 - f1_score: 0.9245 - loss: 0.5505 - val_accuracy: 0.9362 - val_f1_score: 0.9360 - val_loss: 0.4393
# Epoch 29/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 116s 116ms/step - accuracy: 0.9261 - f1_score: 0.9261 - loss: 0.5380 - val_accuracy: 0.9264 - val_f1_score: 0.9261 - val_loss: 0.4302
# Epoch 30/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9288 - f1_score: 0.9287 - loss: 0.5292 - val_accuracy: 0.9261 - val_f1_score: 0.9258 - val_loss: 0.4062
# Epoch 31/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9292 - f1_score: 0.9291 - loss: 0.5195 - val_accuracy: 0.9332 - val_f1_score: 0.9328 - val_loss: 0.4092
# Epoch 32/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 116s 115ms/step - accuracy: 0.9307 - f1_score: 0.9306 - loss: 0.5054 - val_accuracy: 0.9303 - val_f1_score: 0.9300 - val_loss: 0.3962
# Epoch 33/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9323 - f1_score: 0.9323 - loss: 0.4974 - val_accuracy: 0.9321 - val_f1_score: 0.9318 - val_loss: 0.3871
# Epoch 34/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9356 - f1_score: 0.9355 - loss: 0.4879 - val_accuracy: 0.9397 - val_f1_score: 0.9395 - val_loss: 0.3942
# Epoch 35/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 116ms/step - accuracy: 0.9369 - f1_score: 0.9369 - loss: 0.4772 - val_accuracy: 0.9402 - val_f1_score: 0.9399 - val_loss: 0.3760
# Epoch 36/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9389 - f1_score: 0.9389 - loss: 0.4690 - val_accuracy: 0.9323 - val_f1_score: 0.9322 - val_loss: 0.3733
# Epoch 37/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 116s 116ms/step - accuracy: 0.9395 - f1_score: 0.9395 - loss: 0.4610 - val_accuracy: 0.9350 - val_f1_score: 0.9348 - val_loss: 0.3715
# Epoch 38/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9428 - f1_score: 0.9428 - loss: 0.4529 - val_accuracy: 0.9372 - val_f1_score: 0.9369 - val_loss: 0.3577
# Epoch 39/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9444 - f1_score: 0.9444 - loss: 0.4422 - val_accuracy: 0.9408 - val_f1_score: 0.9406 - val_loss: 0.3651
# Epoch 40/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9453 - f1_score: 0.9453 - loss: 0.4351 - val_accuracy: 0.9397 - val_f1_score: 0.9395 - val_loss: 0.3609
# Epoch 41/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 116ms/step - accuracy: 0.9465 - f1_score: 0.9465 - loss: 0.4296 - val_accuracy: 0.9384 - val_f1_score: 0.9382 - val_loss: 0.3426
# Epoch 42/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9501 - f1_score: 0.9501 - loss: 0.4201 - val_accuracy: 0.9440 - val_f1_score: 0.9439 - val_loss: 0.3646
# Epoch 43/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9495 - f1_score: 0.9495 - loss: 0.4119 - val_accuracy: 0.9427 - val_f1_score: 0.9425 - val_loss: 0.3451
# Epoch 44/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9504 - f1_score: 0.9503 - loss: 0.4051 - val_accuracy: 0.9421 - val_f1_score: 0.9420 - val_loss: 0.3467
# Epoch 45/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9521 - f1_score: 0.9521 - loss: 0.3970 - val_accuracy: 0.9446 - val_f1_score: 0.9445 - val_loss: 0.3486
# Epoch 46/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 116ms/step - accuracy: 0.9540 - f1_score: 0.9540 - loss: 0.3904 - val_accuracy: 0.9419 - val_f1_score: 0.9418 - val_loss: 0.3262
# Epoch 47/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9551 - f1_score: 0.9550 - loss: 0.3834 - val_accuracy: 0.9422 - val_f1_score: 0.9421 - val_loss: 0.3409
# Epoch 48/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9552 - f1_score: 0.9552 - loss: 0.3759 - val_accuracy: 0.9434 - val_f1_score: 0.9433 - val_loss: 0.3207
# Epoch 49/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9563 - f1_score: 0.9563 - loss: 0.3713 - val_accuracy: 0.9384 - val_f1_score: 0.9381 - val_loss: 0.3162
# Epoch 50/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9569 - f1_score: 0.9569 - loss: 0.3657 - val_accuracy: 0.9469 - val_f1_score: 0.9468 - val_loss: 0.3204
# Epoch 51/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9604 - f1_score: 0.9604 - loss: 0.3560 - val_accuracy: 0.9433 - val_f1_score: 0.9432 - val_loss: 0.3097
# Epoch 52/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9609 - f1_score: 0.9609 - loss: 0.3529 - val_accuracy: 0.9459 - val_f1_score: 0.9457 - val_loss: 0.3150
# Epoch 53/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9611 - f1_score: 0.9611 - loss: 0.3469 - val_accuracy: 0.9447 - val_f1_score: 0.9447 - val_loss: 0.3391
# Epoch 54/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9630 - f1_score: 0.9630 - loss: 0.3407 - val_accuracy: 0.9450 - val_f1_score: 0.9449 - val_loss: 0.3552
# Epoch 55/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9640 - f1_score: 0.9639 - loss: 0.3343 - val_accuracy: 0.9457 - val_f1_score: 0.9456 - val_loss: 0.3112
# Epoch 56/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9656 - f1_score: 0.9656 - loss: 0.3274 - val_accuracy: 0.9417 - val_f1_score: 0.9414 - val_loss: 0.2915
# Epoch 57/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9652 - f1_score: 0.9652 - loss: 0.3231 - val_accuracy: 0.9436 - val_f1_score: 0.9435 - val_loss: 0.3064
# Epoch 58/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9649 - f1_score: 0.9648 - loss: 0.3164 - val_accuracy: 0.9427 - val_f1_score: 0.9426 - val_loss: 0.3173
# Epoch 59/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9699 - f1_score: 0.9699 - loss: 0.3115 - val_accuracy: 0.9498 - val_f1_score: 0.9496 - val_loss: 0.3073
# Epoch 60/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9669 - f1_score: 0.9669 - loss: 0.3065 - val_accuracy: 0.9484 - val_f1_score: 0.9483 - val_loss: 0.3011
# Epoch 61/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9721 - f1_score: 0.9721 - loss: 0.3012 - val_accuracy: 0.9483 - val_f1_score: 0.9482 - val_loss: 0.2924
# Epoch 62/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9710 - f1_score: 0.9710 - loss: 0.2956 - val_accuracy: 0.9518 - val_f1_score: 0.9517 - val_loss: 0.2983
# Epoch 63/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9713 - f1_score: 0.9713 - loss: 0.2901 - val_accuracy: 0.9404 - val_f1_score: 0.9402 - val_loss: 0.2808
# Epoch 64/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9723 - f1_score: 0.9723 - loss: 0.2878 - val_accuracy: 0.9477 - val_f1_score: 0.9476 - val_loss: 0.2855
# Epoch 65/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9745 - f1_score: 0.9745 - loss: 0.2808 - val_accuracy: 0.9481 - val_f1_score: 0.9480 - val_loss: 0.2812
# Epoch 66/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9735 - f1_score: 0.9735 - loss: 0.2770 - val_accuracy: 0.9451 - val_f1_score: 0.9449 - val_loss: 0.2886
# Epoch 67/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 116ms/step - accuracy: 0.9743 - f1_score: 0.9743 - loss: 0.2732 - val_accuracy: 0.9415 - val_f1_score: 0.9414 - val_loss: 0.2750
# Epoch 68/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9742 - f1_score: 0.9742 - loss: 0.2678 - val_accuracy: 0.9415 - val_f1_score: 0.9413 - val_loss: 0.2682
# Epoch 69/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9753 - f1_score: 0.9753 - loss: 0.2655 - val_accuracy: 0.9493 - val_f1_score: 0.9491 - val_loss: 0.2728
# Epoch 70/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9771 - f1_score: 0.9770 - loss: 0.2582 - val_accuracy: 0.9486 - val_f1_score: 0.9485 - val_loss: 0.2712
# Epoch 71/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9767 - f1_score: 0.9767 - loss: 0.2558 - val_accuracy: 0.9504 - val_f1_score: 0.9503 - val_loss: 0.2668
# Epoch 72/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9795 - f1_score: 0.9795 - loss: 0.2493 - val_accuracy: 0.9452 - val_f1_score: 0.9451 - val_loss: 0.2589
# Epoch 73/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9781 - f1_score: 0.9781 - loss: 0.2458 - val_accuracy: 0.9493 - val_f1_score: 0.9492 - val_loss: 0.2681
# Epoch 74/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9783 - f1_score: 0.9783 - loss: 0.2421 - val_accuracy: 0.9491 - val_f1_score: 0.9490 - val_loss: 0.2592
# Epoch 75/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9796 - f1_score: 0.9796 - loss: 0.2360 - val_accuracy: 0.9479 - val_f1_score: 0.9478 - val_loss: 0.2705
# Epoch 76/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9816 - f1_score: 0.9816 - loss: 0.2337 - val_accuracy: 0.9500 - val_f1_score: 0.9500 - val_loss: 0.2514
# Epoch 77/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9807 - f1_score: 0.9807 - loss: 0.2321 - val_accuracy: 0.9545 - val_f1_score: 0.9543 - val_loss: 0.2547
# Epoch 78/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9827 - f1_score: 0.9827 - loss: 0.2247 - val_accuracy: 0.9418 - val_f1_score: 0.9417 - val_loss: 0.2674
# Epoch 79/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9822 - f1_score: 0.9822 - loss: 0.2219 - val_accuracy: 0.9456 - val_f1_score: 0.9454 - val_loss: 0.2487
# Epoch 80/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9860 - f1_score: 0.9860 - loss: 0.2166 - val_accuracy: 0.9522 - val_f1_score: 0.9520 - val_loss: 0.2478
# Epoch 81/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9829 - f1_score: 0.9829 - loss: 0.2148 - val_accuracy: 0.9348 - val_f1_score: 0.9348 - val_loss: 0.2635
# Epoch 82/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 116ms/step - accuracy: 0.9823 - f1_score: 0.9823 - loss: 0.2126 - val_accuracy: 0.9484 - val_f1_score: 0.9482 - val_loss: 0.2456
# Epoch 83/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9839 - f1_score: 0.9839 - loss: 0.2079 - val_accuracy: 0.9507 - val_f1_score: 0.9506 - val_loss: 0.2611
# Epoch 84/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9836 - f1_score: 0.9836 - loss: 0.2052 - val_accuracy: 0.9351 - val_f1_score: 0.9348 - val_loss: 0.2530
# Epoch 85/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9859 - f1_score: 0.9859 - loss: 0.2013 - val_accuracy: 0.9479 - val_f1_score: 0.9478 - val_loss: 0.2373
# Epoch 86/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 116s 116ms/step - accuracy: 0.9858 - f1_score: 0.9858 - loss: 0.1970 - val_accuracy: 0.9480 - val_f1_score: 0.9479 - val_loss: 0.2339
# Epoch 87/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9858 - f1_score: 0.9858 - loss: 0.1941 - val_accuracy: 0.9519 - val_f1_score: 0.9518 - val_loss: 0.2379
# Epoch 88/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9879 - f1_score: 0.9879 - loss: 0.1895 - val_accuracy: 0.9442 - val_f1_score: 0.9440 - val_loss: 0.2349
# Epoch 89/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9868 - f1_score: 0.9867 - loss: 0.1877 - val_accuracy: 0.9493 - val_f1_score: 0.9493 - val_loss: 0.2528
# Epoch 90/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9880 - f1_score: 0.9880 - loss: 0.1852 - val_accuracy: 0.9378 - val_f1_score: 0.9379 - val_loss: 0.2521
# Epoch 91/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9881 - f1_score: 0.9881 - loss: 0.1803 - val_accuracy: 0.9542 - val_f1_score: 0.9542 - val_loss: 0.2374
# Epoch 92/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9888 - f1_score: 0.9887 - loss: 0.1787 - val_accuracy: 0.9442 - val_f1_score: 0.9442 - val_loss: 0.2460
# Epoch 93/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9894 - f1_score: 0.9893 - loss: 0.1746 - val_accuracy: 0.9429 - val_f1_score: 0.9427 - val_loss: 0.2357
# Epoch 94/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9890 - f1_score: 0.9891 - loss: 0.1739 - val_accuracy: 0.9515 - val_f1_score: 0.9515 - val_loss: 0.2348
# Epoch 95/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9893 - f1_score: 0.9893 - loss: 0.1684 - val_accuracy: 0.9547 - val_f1_score: 0.9546 - val_loss: 0.2251
# Epoch 96/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9899 - f1_score: 0.9899 - loss: 0.1656 - val_accuracy: 0.9418 - val_f1_score: 0.9418 - val_loss: 0.2647
# Epoch 97/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9899 - f1_score: 0.9899 - loss: 0.1649 - val_accuracy: 0.9494 - val_f1_score: 0.9493 - val_loss: 0.2282
# Epoch 98/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9907 - f1_score: 0.9907 - loss: 0.1619 - val_accuracy: 0.9539 - val_f1_score: 0.9539 - val_loss: 0.2290
# Epoch 99/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9904 - f1_score: 0.9904 - loss: 0.1592 - val_accuracy: 0.9509 - val_f1_score: 0.9508 - val_loss: 0.2177
# Epoch 100/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9926 - f1_score: 0.9926 - loss: 0.1536 - val_accuracy: 0.9452 - val_f1_score: 0.9450 - val_loss: 0.2252
# Epoch 101/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9924 - f1_score: 0.9924 - loss: 0.1523 - val_accuracy: 0.9437 - val_f1_score: 0.9434 - val_loss: 0.2254
# Epoch 102/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 116s 116ms/step - accuracy: 0.9922 - f1_score: 0.9922 - loss: 0.1498 - val_accuracy: 0.9526 - val_f1_score: 0.9524 - val_loss: 0.2142
# Epoch 103/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9929 - f1_score: 0.9928 - loss: 0.1468 - val_accuracy: 0.9552 - val_f1_score: 0.9552 - val_loss: 0.2197
# Epoch 104/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9915 - f1_score: 0.9915 - loss: 0.1470 - val_accuracy: 0.9433 - val_f1_score: 0.9432 - val_loss: 0.2244
# Epoch 105/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 116ms/step - accuracy: 0.9930 - f1_score: 0.9930 - loss: 0.1424 - val_accuracy: 0.9462 - val_f1_score: 0.9460 - val_loss: 0.2132
# Epoch 106/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9936 - f1_score: 0.9936 - loss: 0.1403 - val_accuracy: 0.9561 - val_f1_score: 0.9560 - val_loss: 0.2169
# Epoch 107/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9927 - f1_score: 0.9927 - loss: 0.1395 - val_accuracy: 0.9533 - val_f1_score: 0.9532 - val_loss: 0.2065
# Epoch 108/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9938 - f1_score: 0.9937 - loss: 0.1350 - val_accuracy: 0.9541 - val_f1_score: 0.9539 - val_loss: 0.2115
# Epoch 109/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9939 - f1_score: 0.9939 - loss: 0.1340 - val_accuracy: 0.9520 - val_f1_score: 0.9519 - val_loss: 0.2072
# Epoch 110/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9946 - f1_score: 0.9946 - loss: 0.1316 - val_accuracy: 0.9543 - val_f1_score: 0.9543 - val_loss: 0.2140
# Epoch 111/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9946 - f1_score: 0.9946 - loss: 0.1291 - val_accuracy: 0.9500 - val_f1_score: 0.9498 - val_loss: 0.2225
# Epoch 112/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9942 - f1_score: 0.9942 - loss: 0.1288 - val_accuracy: 0.9381 - val_f1_score: 0.9379 - val_loss: 0.2275
# Epoch 113/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9944 - f1_score: 0.9944 - loss: 0.1248 - val_accuracy: 0.9499 - val_f1_score: 0.9499 - val_loss: 0.2032
# Epoch 114/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9929 - f1_score: 0.9929 - loss: 0.1243 - val_accuracy: 0.9562 - val_f1_score: 0.9561 - val_loss: 0.1957
# Epoch 115/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9948 - f1_score: 0.9948 - loss: 0.1220 - val_accuracy: 0.9523 - val_f1_score: 0.9521 - val_loss: 0.1986
# Epoch 116/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9945 - f1_score: 0.9945 - loss: 0.1197 - val_accuracy: 0.9513 - val_f1_score: 0.9511 - val_loss: 0.1995
# Epoch 117/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9951 - f1_score: 0.9951 - loss: 0.1176 - val_accuracy: 0.9491 - val_f1_score: 0.9490 - val_loss: 0.2029
# Epoch 118/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9955 - f1_score: 0.9955 - loss: 0.1158 - val_accuracy: 0.9527 - val_f1_score: 0.9525 - val_loss: 0.1946
# Epoch 119/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9955 - f1_score: 0.9955 - loss: 0.1128 - val_accuracy: 0.9533 - val_f1_score: 0.9533 - val_loss: 0.1993
# Epoch 120/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9958 - f1_score: 0.9958 - loss: 0.1103 - val_accuracy: 0.9545 - val_f1_score: 0.9544 - val_loss: 0.2000
# Epoch 121/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9952 - f1_score: 0.9952 - loss: 0.1109 - val_accuracy: 0.9508 - val_f1_score: 0.9506 - val_loss: 0.1988
# Epoch 122/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9957 - f1_score: 0.9957 - loss: 0.1088 - val_accuracy: 0.9499 - val_f1_score: 0.9497 - val_loss: 0.1963
# Epoch 123/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9957 - f1_score: 0.9957 - loss: 0.1068 - val_accuracy: 0.9532 - val_f1_score: 0.9531 - val_loss: 0.1881
# Epoch 124/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9963 - f1_score: 0.9963 - loss: 0.1037 - val_accuracy: 0.9340 - val_f1_score: 0.9335 - val_loss: 0.2311
# Epoch 125/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9970 - f1_score: 0.9970 - loss: 0.1024 - val_accuracy: 0.9558 - val_f1_score: 0.9557 - val_loss: 0.1920
# Epoch 126/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9959 - f1_score: 0.9959 - loss: 0.1018 - val_accuracy: 0.9409 - val_f1_score: 0.9409 - val_loss: 0.2305
# Epoch 127/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9963 - f1_score: 0.9963 - loss: 0.1007 - val_accuracy: 0.9510 - val_f1_score: 0.9510 - val_loss: 0.1920
# Epoch 128/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9968 - f1_score: 0.9968 - loss: 0.0987 - val_accuracy: 0.9546 - val_f1_score: 0.9545 - val_loss: 0.1889
# Epoch 129/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 116s 116ms/step - accuracy: 0.9971 - f1_score: 0.9971 - loss: 0.0962 - val_accuracy: 0.9523 - val_f1_score: 0.9523 - val_loss: 0.1880
# Epoch 130/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 116s 115ms/step - accuracy: 0.9969 - f1_score: 0.9969 - loss: 0.0939 - val_accuracy: 0.9493 - val_f1_score: 0.9492 - val_loss: 0.2043
# Epoch 131/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9971 - f1_score: 0.9971 - loss: 0.0935 - val_accuracy: 0.9518 - val_f1_score: 0.9518 - val_loss: 0.1980
# Epoch 132/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9973 - f1_score: 0.9973 - loss: 0.0916 - val_accuracy: 0.9518 - val_f1_score: 0.9517 - val_loss: 0.2084
# Epoch 133/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9970 - f1_score: 0.9970 - loss: 0.0898 - val_accuracy: 0.9552 - val_f1_score: 0.9552 - val_loss: 0.1892
# Epoch 134/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9971 - f1_score: 0.9971 - loss: 0.0893 - val_accuracy: 0.9507 - val_f1_score: 0.9505 - val_loss: 0.1935
# Epoch 135/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9972 - f1_score: 0.9972 - loss: 0.0876 - val_accuracy: 0.9534 - val_f1_score: 0.9534 - val_loss: 0.1830
# Epoch 136/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9976 - f1_score: 0.9976 - loss: 0.0861 - val_accuracy: 0.9441 - val_f1_score: 0.9439 - val_loss: 0.2020
# Epoch 137/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9976 - f1_score: 0.9976 - loss: 0.0846 - val_accuracy: 0.9498 - val_f1_score: 0.9496 - val_loss: 0.1902
# Epoch 138/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9967 - f1_score: 0.9967 - loss: 0.0851 - val_accuracy: 0.9566 - val_f1_score: 0.9566 - val_loss: 0.1815
# Epoch 139/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9977 - f1_score: 0.9977 - loss: 0.0818 - val_accuracy: 0.9462 - val_f1_score: 0.9459 - val_loss: 0.1931
# Epoch 140/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9965 - f1_score: 0.9965 - loss: 0.0820 - val_accuracy: 0.9490 - val_f1_score: 0.9489 - val_loss: 0.1872
# Epoch 141/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9975 - f1_score: 0.9975 - loss: 0.0811 - val_accuracy: 0.9539 - val_f1_score: 0.9537 - val_loss: 0.1894
# Epoch 142/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9972 - f1_score: 0.9972 - loss: 0.0789 - val_accuracy: 0.9575 - val_f1_score: 0.9574 - val_loss: 0.1801
# Epoch 143/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9980 - f1_score: 0.9980 - loss: 0.0765 - val_accuracy: 0.9579 - val_f1_score: 0.9578 - val_loss: 0.1790
# Epoch 144/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9982 - f1_score: 0.9982 - loss: 0.0759 - val_accuracy: 0.9548 - val_f1_score: 0.9547 - val_loss: 0.1787
# Epoch 145/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9973 - f1_score: 0.9973 - loss: 0.0763 - val_accuracy: 0.9564 - val_f1_score: 0.9563 - val_loss: 0.1785
# Epoch 146/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9974 - f1_score: 0.9974 - loss: 0.0739 - val_accuracy: 0.9518 - val_f1_score: 0.9516 - val_loss: 0.1890
# Epoch 147/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9972 - f1_score: 0.9972 - loss: 0.0740 - val_accuracy: 0.9566 - val_f1_score: 0.9565 - val_loss: 0.1747
# Epoch 148/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9982 - f1_score: 0.9982 - loss: 0.0714 - val_accuracy: 0.9590 - val_f1_score: 0.9589 - val_loss: 0.1705
# Epoch 149/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9980 - f1_score: 0.9980 - loss: 0.0699 - val_accuracy: 0.9552 - val_f1_score: 0.9550 - val_loss: 0.1804
# Epoch 150/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 115s 115ms/step - accuracy: 0.9980 - f1_score: 0.9980 - loss: 0.0691 - val_accuracy: 0.9437 - val_f1_score: 0.9434 - val_loss: 0.2024
# Restoring model weights from the end of the best epoch: 148.

# %%
model.save('/content/drive/MyDrive/Universidad/Investigacion/models/graph_1.keras')

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
train_f1 = history.history['f1_score']
val_f1 = history.history['val_f1_score']

# %%
length = len(history.history['accuracy'])

# %%
import matplotlib.pyplot as plt

plt.plot(range(1, length+1), train_loss, label='Train Loss')
plt.plot(range(1, length+1), val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curves')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(range(1, length+1), train_f1, label='Train F1')
plt.plot(range(1, length+1), val_f1, label='Validation F1')
plt.xlabel('Epoch')
plt.ylabel('F1')
plt.title('F1 Curves')
plt.legend()
plt.show()
