# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers
# !pip install -U gensim
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.4.4)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.0.0)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 98.6 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
import tensorflow as tf
import numpy as np
import random
import os

SEED = 2025

os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
tf.config.experimental.enable_op_determinism()

# %%
import tensorflow as tf

print("GPU available:", tf.config.list_physical_devices('GPU'))

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        print(e)
# Out:
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 1 Physical GPUs, 1 Logical GPUs

# %%
import tensorflow as tf

dataset_train = tf.data.Dataset.load("/content/drive/MyDrive/Universidad/Investigacion/tf_datasets_3/train")

# %%
from tensorflow.keras.layers import Dense, Input, Dropout, Bidirectional, LSTM, Embedding, BatchNormalization, Reshape, Conv2D, MaxPool2D, concatenate, Flatten
from tensorflow.keras.layers import Conv1D, GlobalMaxPooling1D, MaxPooling1D, Input, Bidirectional, GRU, Flatten, concatenate, BatchNormalization, Dense, LeakyReLU, Activation
from tensorflow.keras.models import Model
from keras import regularizers

num_classes = 8

def create_input_branch(input_shape, name):
    input_layer = Input(shape=input_shape, name=name)
    dense1 = Dense(10000)(input_layer)
    batch1 = BatchNormalization()(dense1)
    activation1 = Activation('relu')(batch1)
    drop1 = Dropout(0.2)(activation1)

    dense2 = Dense(1000)(drop1)
    batch2 = BatchNormalization()(dense2)
    activation2 = Activation('relu')(batch2)
    drop2 = Dropout(0.2)(activation2)

    dense3 = Dense(100)(drop2)
    batch3 = BatchNormalization()(dense3)
    activation3 = Activation('relu')(batch3)
    drop3 = Dropout(0.2)(activation3)

    dense4 = Dense(10)(drop3)
    batch4 = BatchNormalization()(dense4)
    activation4 = Activation('relu')(batch4)
    drop4 = Dropout(0.2)(activation4)
    return input_layer, drop4

input_nl, output_nl = create_input_branch((768,), "nl")
input_pl, output_pl = create_input_branch((768,), "pl")
input_initial, output_initial = create_input_branch((768,), "initial")
input_transformation, output_transformation = create_input_branch((768,), "transformation")
input_js, output_js = create_input_branch((768,), "js")
input_final, output_final = create_input_branch((768,), "final")


concat = concatenate([output_nl, output_pl, output_initial, output_transformation, output_js, output_final])

output = Dense(num_classes)(concat)
output = BatchNormalization()(output)
output = Activation('softmax')(output)

model = Model(inputs=[input_nl, input_pl, input_initial, input_transformation, input_js, input_final], outputs=output)

# %%
# %%time
from tensorflow.keras.optimizers import Adam
adam = Adam(learning_rate=0.00001)

model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy', tf.keras.metrics.F1Score(average='macro')])

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ nl (InputLayer)     │ (None, 768)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pl (InputLayer)     │ (None, 768)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ initial             │ (None, 768)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformation      │ (None, 768)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ js (InputLayer)     │ (None, 768)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final (InputLayer)  │ (None, 768)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 10000)     │  7,690,000 │ nl[0][0]          │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 10000)     │  7,690,000 │ pl[0][0]          │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 10000)     │  7,690,000 │ initial[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 10000)     │  7,690,000 │ transformation[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 10000)     │  7,690,000 │ js[0][0]          │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 10000)     │  7,690,000 │ final[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 10000)     │     40,000 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_4[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_8[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_12[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_16[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_20[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 10000)     │          0 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 10000)     │          0 │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 10000)     │          0 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 10000)     │          0 │ activation_12[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 10000)     │          0 │ activation_16[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 10000)     │          0 │ activation_20[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1000)      │ 10,001,000 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 1000)      │ 10,001,000 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 1000)      │ 10,001,000 │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 1000)      │ 10,001,000 │ dropout_12[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 1000)      │ 10,001,000 │ dropout_16[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_21 (Dense)    │ (None, 1000)      │ 10,001,000 │ dropout_20[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1000)      │      4,000 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1000)      │      4,000 │ dense_5[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1000)      │      4,000 │ dense_9[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1000)      │      4,000 │ dense_13[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1000)      │      4,000 │ dense_17[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1000)      │      4,000 │ dense_21[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 1000)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 1000)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 1000)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 1000)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 1000)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 1000)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 1000)      │          0 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 1000)      │          0 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 1000)      │          0 │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 1000)      │          0 │ activation_13[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 1000)      │          0 │ activation_17[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_21          │ (None, 1000)      │          0 │ activation_21[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 100)       │    100,100 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 100)       │    100,100 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 100)       │    100,100 │ dropout_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 100)       │    100,100 │ dropout_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 100)       │    100,100 │ dropout_17[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_22 (Dense)    │ (None, 100)       │    100,100 │ dropout_21[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100)       │        400 │ dense_2[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100)       │        400 │ dense_6[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100)       │        400 │ dense_10[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100)       │        400 │ dense_14[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100)       │        400 │ dense_18[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100)       │        400 │ dense_22[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 100)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 100)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 100)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 100)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 100)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 100)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 100)       │          0 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 100)       │          0 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 100)       │          0 │ activation_10[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 100)       │          0 │ activation_14[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_18          │ (None, 100)       │          0 │ activation_18[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 100)       │          0 │ activation_22[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 10)        │      1,010 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 10)        │      1,010 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 10)        │      1,010 │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 10)        │      1,010 │ dropout_14[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 10)        │      1,010 │ dropout_18[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_23 (Dense)    │ (None, 10)        │      1,010 │ dropout_22[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10)        │         40 │ dense_3[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10)        │         40 │ dense_7[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10)        │         40 │ dense_11[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10)        │         40 │ dense_15[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10)        │         40 │ dense_19[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10)        │         40 │ dense_23[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 10)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 10)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 10)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 10)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 10)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 10)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 10)        │          0 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 10)        │          0 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 10)        │          0 │ activation_11[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, 10)        │          0 │ activation_15[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 10)        │          0 │ activation_19[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 10)        │          0 │ activation_23[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 60)        │          0 │ dropout_3[0][0],  │
# │ (Concatenate)       │                   │            │ dropout_7[0][0],  │
# │                     │                   │            │ dropout_11[0][0], │
# │                     │                   │            │ dropout_15[0][0], │
# │                     │                   │            │ dropout_19[0][0], │
# │                     │                   │            │ dropout_23[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_24 (Dense)    │ (None, 8)         │        488 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8)         │         32 │ dense_24[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 8)         │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 107,019,820 (408.25 MB)
#  Trainable params: 106,886,484 (407.74 MB)
#  Non-trainable params: 133,336 (520.84 KB)
# CPU times: user 105 ms, sys: 7.6 ms, total: 112 ms
# Wall time: 113 ms

# %%
from tensorflow.keras.callbacks import EarlyStopping

total_size = dataset_train.reduce(0, lambda x, _: x + 1).numpy()
val_size = int(0.2 * total_size)

dataset_train = dataset_train.shuffle(
    buffer_size=total_size,
    seed=SEED,
    reshuffle_each_iteration=False
)

val_dataset = dataset_train.take(val_size)
train_dataset = dataset_train.skip(val_size)



epochs=150

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)


history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=epochs,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 110s 92ms/step - accuracy: 0.2321 - f1_score: 0.2306 - loss: 2.0040 - val_accuracy: 0.4537 - val_f1_score: 0.4494 - val_loss: 1.5283
# Epoch 2/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.3664 - f1_score: 0.3644 - loss: 1.6474 - val_accuracy: 0.5622 - val_f1_score: 0.5567 - val_loss: 1.3649
# Epoch 3/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.4361 - f1_score: 0.4330 - loss: 1.5215 - val_accuracy: 0.6468 - val_f1_score: 0.6412 - val_loss: 1.2583
# Epoch 4/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.4893 - f1_score: 0.4858 - loss: 1.4288 - val_accuracy: 0.7002 - val_f1_score: 0.6947 - val_loss: 1.1835
# Epoch 5/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.5343 - f1_score: 0.5311 - loss: 1.3610 - val_accuracy: 0.7308 - val_f1_score: 0.7262 - val_loss: 1.1445
# Epoch 6/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.5669 - f1_score: 0.5644 - loss: 1.3054 - val_accuracy: 0.7511 - val_f1_score: 0.7470 - val_loss: 1.0832
# Epoch 7/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.5941 - f1_score: 0.5918 - loss: 1.2559 - val_accuracy: 0.7653 - val_f1_score: 0.7629 - val_loss: 1.0398
# Epoch 8/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.6310 - f1_score: 0.6288 - loss: 1.2059 - val_accuracy: 0.7916 - val_f1_score: 0.7882 - val_loss: 1.0032
# Epoch 9/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.6545 - f1_score: 0.6525 - loss: 1.1654 - val_accuracy: 0.8105 - val_f1_score: 0.8086 - val_loss: 0.9718
# Epoch 10/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.6813 - f1_score: 0.6800 - loss: 1.1256 - val_accuracy: 0.8293 - val_f1_score: 0.8279 - val_loss: 0.9299
# Epoch 11/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.6959 - f1_score: 0.6942 - loss: 1.0969 - val_accuracy: 0.8335 - val_f1_score: 0.8321 - val_loss: 0.9018
# Epoch 12/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.7131 - f1_score: 0.7118 - loss: 1.0648 - val_accuracy: 0.8549 - val_f1_score: 0.8540 - val_loss: 0.8609
# Epoch 13/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.7319 - f1_score: 0.7308 - loss: 1.0343 - val_accuracy: 0.8620 - val_f1_score: 0.8613 - val_loss: 0.8355
# Epoch 14/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.7468 - f1_score: 0.7455 - loss: 1.0055 - val_accuracy: 0.8665 - val_f1_score: 0.8659 - val_loss: 0.8215
# Epoch 15/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.7618 - f1_score: 0.7607 - loss: 0.9804 - val_accuracy: 0.8742 - val_f1_score: 0.8740 - val_loss: 0.8143
# Epoch 16/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.7700 - f1_score: 0.7693 - loss: 0.9614 - val_accuracy: 0.8792 - val_f1_score: 0.8788 - val_loss: 0.7740
# Epoch 17/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.7829 - f1_score: 0.7823 - loss: 0.9373 - val_accuracy: 0.8778 - val_f1_score: 0.8774 - val_loss: 0.7614
# Epoch 18/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.7950 - f1_score: 0.7944 - loss: 0.9173 - val_accuracy: 0.8921 - val_f1_score: 0.8919 - val_loss: 0.7256
# Epoch 19/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8011 - f1_score: 0.8006 - loss: 0.8989 - val_accuracy: 0.8914 - val_f1_score: 0.8914 - val_loss: 0.7238
# Epoch 20/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8119 - f1_score: 0.8114 - loss: 0.8791 - val_accuracy: 0.8928 - val_f1_score: 0.8926 - val_loss: 0.7058
# Epoch 21/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8236 - f1_score: 0.8234 - loss: 0.8549 - val_accuracy: 0.8954 - val_f1_score: 0.8952 - val_loss: 0.6875
# Epoch 22/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8252 - f1_score: 0.8248 - loss: 0.8426 - val_accuracy: 0.9035 - val_f1_score: 0.9035 - val_loss: 0.6782
# Epoch 23/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8332 - f1_score: 0.8328 - loss: 0.8287 - val_accuracy: 0.8965 - val_f1_score: 0.8966 - val_loss: 0.6510
# Epoch 24/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8384 - f1_score: 0.8381 - loss: 0.8119 - val_accuracy: 0.9008 - val_f1_score: 0.9010 - val_loss: 0.6352
# Epoch 25/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8457 - f1_score: 0.8454 - loss: 0.7931 - val_accuracy: 0.9085 - val_f1_score: 0.9084 - val_loss: 0.6312
# Epoch 26/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8467 - f1_score: 0.8465 - loss: 0.7810 - val_accuracy: 0.9074 - val_f1_score: 0.9077 - val_loss: 0.6146
# Epoch 27/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8554 - f1_score: 0.8553 - loss: 0.7642 - val_accuracy: 0.9100 - val_f1_score: 0.9102 - val_loss: 0.6020
# Epoch 28/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8589 - f1_score: 0.8588 - loss: 0.7526 - val_accuracy: 0.9068 - val_f1_score: 0.9068 - val_loss: 0.5847
# Epoch 29/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8626 - f1_score: 0.8624 - loss: 0.7386 - val_accuracy: 0.9145 - val_f1_score: 0.9147 - val_loss: 0.5788
# Epoch 30/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8666 - f1_score: 0.8664 - loss: 0.7267 - val_accuracy: 0.9092 - val_f1_score: 0.9091 - val_loss: 0.5619
# Epoch 31/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.8708 - f1_score: 0.8707 - loss: 0.7067 - val_accuracy: 0.9094 - val_f1_score: 0.9095 - val_loss: 0.5668
# Epoch 32/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8737 - f1_score: 0.8735 - loss: 0.7000 - val_accuracy: 0.9186 - val_f1_score: 0.9188 - val_loss: 0.5520
# Epoch 33/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8784 - f1_score: 0.8782 - loss: 0.6842 - val_accuracy: 0.9155 - val_f1_score: 0.9157 - val_loss: 0.5347
# Epoch 34/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.8784 - f1_score: 0.8783 - loss: 0.6769 - val_accuracy: 0.9208 - val_f1_score: 0.9209 - val_loss: 0.5288
# Epoch 35/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8801 - f1_score: 0.8801 - loss: 0.6664 - val_accuracy: 0.9221 - val_f1_score: 0.9222 - val_loss: 0.5236
# Epoch 36/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.8887 - f1_score: 0.8886 - loss: 0.6510 - val_accuracy: 0.9186 - val_f1_score: 0.9184 - val_loss: 0.5276
# Epoch 37/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8861 - f1_score: 0.8859 - loss: 0.6461 - val_accuracy: 0.9197 - val_f1_score: 0.9198 - val_loss: 0.5031
# Epoch 38/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8867 - f1_score: 0.8866 - loss: 0.6383 - val_accuracy: 0.9321 - val_f1_score: 0.9321 - val_loss: 0.4982
# Epoch 39/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8950 - f1_score: 0.8949 - loss: 0.6203 - val_accuracy: 0.9231 - val_f1_score: 0.9230 - val_loss: 0.4876
# Epoch 40/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8938 - f1_score: 0.8937 - loss: 0.6153 - val_accuracy: 0.9261 - val_f1_score: 0.9259 - val_loss: 0.4644
# Epoch 41/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8971 - f1_score: 0.8970 - loss: 0.6031 - val_accuracy: 0.9194 - val_f1_score: 0.9194 - val_loss: 0.4710
# Epoch 42/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 91s 90ms/step - accuracy: 0.8986 - f1_score: 0.8986 - loss: 0.5954 - val_accuracy: 0.9297 - val_f1_score: 0.9295 - val_loss: 0.4425
# Epoch 43/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8995 - f1_score: 0.8995 - loss: 0.5883 - val_accuracy: 0.9289 - val_f1_score: 0.9289 - val_loss: 0.4443
# Epoch 44/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9047 - f1_score: 0.9046 - loss: 0.5789 - val_accuracy: 0.9351 - val_f1_score: 0.9350 - val_loss: 0.4492
# Epoch 45/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9077 - f1_score: 0.9077 - loss: 0.5670 - val_accuracy: 0.9257 - val_f1_score: 0.9258 - val_loss: 0.4337
# Epoch 46/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9083 - f1_score: 0.9082 - loss: 0.5607 - val_accuracy: 0.9366 - val_f1_score: 0.9365 - val_loss: 0.4212
# Epoch 47/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.9113 - f1_score: 0.9112 - loss: 0.5518 - val_accuracy: 0.9264 - val_f1_score: 0.9262 - val_loss: 0.4251
# Epoch 48/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9094 - f1_score: 0.9093 - loss: 0.5472 - val_accuracy: 0.9333 - val_f1_score: 0.9331 - val_loss: 0.4135
# Epoch 49/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9153 - f1_score: 0.9152 - loss: 0.5352 - val_accuracy: 0.9232 - val_f1_score: 0.9233 - val_loss: 0.4108
# Epoch 50/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9148 - f1_score: 0.9147 - loss: 0.5266 - val_accuracy: 0.9285 - val_f1_score: 0.9283 - val_loss: 0.4072
# Epoch 51/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9153 - f1_score: 0.9152 - loss: 0.5184 - val_accuracy: 0.9336 - val_f1_score: 0.9337 - val_loss: 0.4023
# Epoch 52/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 91s 90ms/step - accuracy: 0.9188 - f1_score: 0.9187 - loss: 0.5155 - val_accuracy: 0.9184 - val_f1_score: 0.9183 - val_loss: 0.3952
# Epoch 53/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9203 - f1_score: 0.9202 - loss: 0.5071 - val_accuracy: 0.9305 - val_f1_score: 0.9305 - val_loss: 0.3902
# Epoch 54/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9225 - f1_score: 0.9225 - loss: 0.5015 - val_accuracy: 0.9300 - val_f1_score: 0.9301 - val_loss: 0.3848
# Epoch 55/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9217 - f1_score: 0.9217 - loss: 0.4983 - val_accuracy: 0.9307 - val_f1_score: 0.9305 - val_loss: 0.3845
# Epoch 56/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9214 - f1_score: 0.9213 - loss: 0.4888 - val_accuracy: 0.9351 - val_f1_score: 0.9349 - val_loss: 0.3667
# Epoch 57/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9260 - f1_score: 0.9259 - loss: 0.4821 - val_accuracy: 0.9365 - val_f1_score: 0.9361 - val_loss: 0.3798
# Epoch 58/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9263 - f1_score: 0.9263 - loss: 0.4752 - val_accuracy: 0.9383 - val_f1_score: 0.9382 - val_loss: 0.3650
# Epoch 59/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9272 - f1_score: 0.9271 - loss: 0.4698 - val_accuracy: 0.9419 - val_f1_score: 0.9417 - val_loss: 0.3717
# Epoch 60/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9315 - f1_score: 0.9315 - loss: 0.4637 - val_accuracy: 0.9238 - val_f1_score: 0.9235 - val_loss: 0.3616
# Epoch 61/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 91s 91ms/step - accuracy: 0.9293 - f1_score: 0.9293 - loss: 0.4604 - val_accuracy: 0.9389 - val_f1_score: 0.9388 - val_loss: 0.3489
# Epoch 62/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9319 - f1_score: 0.9318 - loss: 0.4530 - val_accuracy: 0.9359 - val_f1_score: 0.9358 - val_loss: 0.3520
# Epoch 63/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9339 - f1_score: 0.9338 - loss: 0.4463 - val_accuracy: 0.9243 - val_f1_score: 0.9244 - val_loss: 0.3537
# Epoch 64/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9323 - f1_score: 0.9322 - loss: 0.4430 - val_accuracy: 0.9297 - val_f1_score: 0.9295 - val_loss: 0.3482
# Epoch 65/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9354 - f1_score: 0.9354 - loss: 0.4365 - val_accuracy: 0.9414 - val_f1_score: 0.9412 - val_loss: 0.3306
# Epoch 66/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9385 - f1_score: 0.9385 - loss: 0.4295 - val_accuracy: 0.9476 - val_f1_score: 0.9474 - val_loss: 0.3251
# Epoch 67/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9369 - f1_score: 0.9369 - loss: 0.4230 - val_accuracy: 0.9381 - val_f1_score: 0.9380 - val_loss: 0.3291
# Epoch 68/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9372 - f1_score: 0.9372 - loss: 0.4216 - val_accuracy: 0.9451 - val_f1_score: 0.9449 - val_loss: 0.3259
# Epoch 69/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9401 - f1_score: 0.9400 - loss: 0.4117 - val_accuracy: 0.9335 - val_f1_score: 0.9332 - val_loss: 0.3253
# Epoch 70/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9395 - f1_score: 0.9394 - loss: 0.4094 - val_accuracy: 0.9290 - val_f1_score: 0.9286 - val_loss: 0.3323
# Epoch 71/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9426 - f1_score: 0.9426 - loss: 0.4059 - val_accuracy: 0.9307 - val_f1_score: 0.9304 - val_loss: 0.3201
# Epoch 72/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 91s 91ms/step - accuracy: 0.9423 - f1_score: 0.9423 - loss: 0.3991 - val_accuracy: 0.9434 - val_f1_score: 0.9433 - val_loss: 0.3117
# Epoch 73/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 91ms/step - accuracy: 0.9446 - f1_score: 0.9445 - loss: 0.3918 - val_accuracy: 0.9328 - val_f1_score: 0.9327 - val_loss: 0.3169
# Epoch 74/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9458 - f1_score: 0.9457 - loss: 0.3887 - val_accuracy: 0.9250 - val_f1_score: 0.9248 - val_loss: 0.3211
# Epoch 75/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9464 - f1_score: 0.9463 - loss: 0.3839 - val_accuracy: 0.9432 - val_f1_score: 0.9430 - val_loss: 0.2970
# Epoch 76/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9456 - f1_score: 0.9456 - loss: 0.3792 - val_accuracy: 0.9391 - val_f1_score: 0.9390 - val_loss: 0.3007
# Epoch 77/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9462 - f1_score: 0.9462 - loss: 0.3754 - val_accuracy: 0.9370 - val_f1_score: 0.9367 - val_loss: 0.2959
# Epoch 78/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9495 - f1_score: 0.9495 - loss: 0.3720 - val_accuracy: 0.9409 - val_f1_score: 0.9408 - val_loss: 0.2949
# Epoch 79/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9510 - f1_score: 0.9509 - loss: 0.3675 - val_accuracy: 0.9313 - val_f1_score: 0.9309 - val_loss: 0.3108
# Epoch 80/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9477 - f1_score: 0.9477 - loss: 0.3649 - val_accuracy: 0.9369 - val_f1_score: 0.9366 - val_loss: 0.2967
# Epoch 81/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9510 - f1_score: 0.9510 - loss: 0.3594 - val_accuracy: 0.9469 - val_f1_score: 0.9465 - val_loss: 0.2909
# Epoch 82/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9500 - f1_score: 0.9500 - loss: 0.3534 - val_accuracy: 0.9248 - val_f1_score: 0.9249 - val_loss: 0.3087
# Epoch 83/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9510 - f1_score: 0.9509 - loss: 0.3530 - val_accuracy: 0.9409 - val_f1_score: 0.9408 - val_loss: 0.2845
# Epoch 84/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9533 - f1_score: 0.9533 - loss: 0.3470 - val_accuracy: 0.9443 - val_f1_score: 0.9442 - val_loss: 0.2789
# Epoch 85/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9541 - f1_score: 0.9540 - loss: 0.3449 - val_accuracy: 0.9338 - val_f1_score: 0.9337 - val_loss: 0.2878
# Epoch 86/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 91s 91ms/step - accuracy: 0.9554 - f1_score: 0.9554 - loss: 0.3401 - val_accuracy: 0.9374 - val_f1_score: 0.9372 - val_loss: 0.2855
# Epoch 87/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9547 - f1_score: 0.9547 - loss: 0.3341 - val_accuracy: 0.9475 - val_f1_score: 0.9471 - val_loss: 0.2847
# Epoch 88/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 91s 90ms/step - accuracy: 0.9544 - f1_score: 0.9544 - loss: 0.3333 - val_accuracy: 0.9394 - val_f1_score: 0.9395 - val_loss: 0.2787
# Epoch 89/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9580 - f1_score: 0.9579 - loss: 0.3271 - val_accuracy: 0.9391 - val_f1_score: 0.9390 - val_loss: 0.2745
# Epoch 90/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9572 - f1_score: 0.9572 - loss: 0.3263 - val_accuracy: 0.9459 - val_f1_score: 0.9456 - val_loss: 0.2702
# Epoch 91/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9581 - f1_score: 0.9580 - loss: 0.3209 - val_accuracy: 0.9285 - val_f1_score: 0.9283 - val_loss: 0.2956
# Epoch 92/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9575 - f1_score: 0.9575 - loss: 0.3183 - val_accuracy: 0.9481 - val_f1_score: 0.9477 - val_loss: 0.2577
# Epoch 93/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9584 - f1_score: 0.9583 - loss: 0.3148 - val_accuracy: 0.9427 - val_f1_score: 0.9424 - val_loss: 0.2577
# Epoch 94/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9563 - f1_score: 0.9563 - loss: 0.3141 - val_accuracy: 0.9364 - val_f1_score: 0.9361 - val_loss: 0.2801
# Epoch 95/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9610 - f1_score: 0.9610 - loss: 0.3078 - val_accuracy: 0.9211 - val_f1_score: 0.9206 - val_loss: 0.2988
# Epoch 96/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9623 - f1_score: 0.9622 - loss: 0.3039 - val_accuracy: 0.9527 - val_f1_score: 0.9523 - val_loss: 0.2453
# Epoch 97/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.9609 - f1_score: 0.9608 - loss: 0.3018 - val_accuracy: 0.9305 - val_f1_score: 0.9304 - val_loss: 0.2766
# Epoch 98/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.9640 - f1_score: 0.9639 - loss: 0.2928 - val_accuracy: 0.9518 - val_f1_score: 0.9516 - val_loss: 0.2450
# Epoch 99/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.9620 - f1_score: 0.9620 - loss: 0.2954 - val_accuracy: 0.9426 - val_f1_score: 0.9424 - val_loss: 0.2499
# Epoch 100/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.9608 - f1_score: 0.9608 - loss: 0.2937 - val_accuracy: 0.9352 - val_f1_score: 0.9349 - val_loss: 0.2624
# Epoch 101/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9629 - f1_score: 0.9629 - loss: 0.2885 - val_accuracy: 0.9388 - val_f1_score: 0.9386 - val_loss: 0.2601
# Epoch 102/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 91s 91ms/step - accuracy: 0.9642 - f1_score: 0.9641 - loss: 0.2861 - val_accuracy: 0.9429 - val_f1_score: 0.9427 - val_loss: 0.2524
# Epoch 103/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9635 - f1_score: 0.9635 - loss: 0.2849 - val_accuracy: 0.9409 - val_f1_score: 0.9407 - val_loss: 0.2484
# Epoch 104/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9679 - f1_score: 0.9678 - loss: 0.2786 - val_accuracy: 0.9451 - val_f1_score: 0.9449 - val_loss: 0.2342
# Epoch 105/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.9648 - f1_score: 0.9647 - loss: 0.2761 - val_accuracy: 0.9340 - val_f1_score: 0.9339 - val_loss: 0.2647
# Epoch 106/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.9670 - f1_score: 0.9670 - loss: 0.2698 - val_accuracy: 0.9508 - val_f1_score: 0.9506 - val_loss: 0.2346
# Epoch 107/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.9661 - f1_score: 0.9661 - loss: 0.2719 - val_accuracy: 0.9462 - val_f1_score: 0.9459 - val_loss: 0.2378
# Epoch 108/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.9662 - f1_score: 0.9661 - loss: 0.2696 - val_accuracy: 0.9346 - val_f1_score: 0.9343 - val_loss: 0.2644
# Epoch 109/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9668 - f1_score: 0.9668 - loss: 0.2652 - val_accuracy: 0.9442 - val_f1_score: 0.9439 - val_loss: 0.2406
# Epoch 110/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.9676 - f1_score: 0.9676 - loss: 0.2640 - val_accuracy: 0.9307 - val_f1_score: 0.9303 - val_loss: 0.2681
# Epoch 111/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9664 - f1_score: 0.9664 - loss: 0.2592 - val_accuracy: 0.9404 - val_f1_score: 0.9403 - val_loss: 0.2417
# Epoch 112/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9700 - f1_score: 0.9699 - loss: 0.2541 - val_accuracy: 0.9355 - val_f1_score: 0.9352 - val_loss: 0.2621
# Epoch 113/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 91s 91ms/step - accuracy: 0.9666 - f1_score: 0.9665 - loss: 0.2562 - val_accuracy: 0.9484 - val_f1_score: 0.9481 - val_loss: 0.2265
# Epoch 114/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9728 - f1_score: 0.9728 - loss: 0.2461 - val_accuracy: 0.9457 - val_f1_score: 0.9455 - val_loss: 0.2293
# Epoch 115/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9709 - f1_score: 0.9708 - loss: 0.2489 - val_accuracy: 0.9359 - val_f1_score: 0.9355 - val_loss: 0.2440
# Epoch 116/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9703 - f1_score: 0.9703 - loss: 0.2463 - val_accuracy: 0.9371 - val_f1_score: 0.9366 - val_loss: 0.2431
# Epoch 117/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9740 - f1_score: 0.9740 - loss: 0.2407 - val_accuracy: 0.9362 - val_f1_score: 0.9359 - val_loss: 0.2483
# Epoch 118/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9723 - f1_score: 0.9723 - loss: 0.2390 - val_accuracy: 0.9402 - val_f1_score: 0.9398 - val_loss: 0.2421
# Epoch 119/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9720 - f1_score: 0.9720 - loss: 0.2384 - val_accuracy: 0.9505 - val_f1_score: 0.9504 - val_loss: 0.2127
# Epoch 120/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.9707 - f1_score: 0.9706 - loss: 0.2374 - val_accuracy: 0.9480 - val_f1_score: 0.9478 - val_loss: 0.2192
# Epoch 121/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.9736 - f1_score: 0.9735 - loss: 0.2336 - val_accuracy: 0.9290 - val_f1_score: 0.9287 - val_loss: 0.2654
# Epoch 122/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9723 - f1_score: 0.9723 - loss: 0.2347 - val_accuracy: 0.9340 - val_f1_score: 0.9336 - val_loss: 0.2451
# Epoch 123/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9730 - f1_score: 0.9729 - loss: 0.2268 - val_accuracy: 0.9419 - val_f1_score: 0.9417 - val_loss: 0.2261
# Epoch 124/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.9729 - f1_score: 0.9729 - loss: 0.2321 - val_accuracy: 0.9336 - val_f1_score: 0.9333 - val_loss: 0.2458
# Epoch 125/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9737 - f1_score: 0.9737 - loss: 0.2256 - val_accuracy: 0.9509 - val_f1_score: 0.9506 - val_loss: 0.2111
# Epoch 126/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9752 - f1_score: 0.9752 - loss: 0.2191 - val_accuracy: 0.9479 - val_f1_score: 0.9477 - val_loss: 0.2100
# Epoch 127/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.9747 - f1_score: 0.9746 - loss: 0.2206 - val_accuracy: 0.9393 - val_f1_score: 0.9390 - val_loss: 0.2330
# Epoch 128/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9742 - f1_score: 0.9741 - loss: 0.2181 - val_accuracy: 0.9489 - val_f1_score: 0.9486 - val_loss: 0.2181
# Epoch 129/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.9745 - f1_score: 0.9745 - loss: 0.2179 - val_accuracy: 0.9280 - val_f1_score: 0.9275 - val_loss: 0.2622
# Epoch 130/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9732 - f1_score: 0.9731 - loss: 0.2182 - val_accuracy: 0.9397 - val_f1_score: 0.9393 - val_loss: 0.2326
# Epoch 131/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9763 - f1_score: 0.9762 - loss: 0.2117 - val_accuracy: 0.9450 - val_f1_score: 0.9446 - val_loss: 0.2150
# Epoch 132/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 91s 91ms/step - accuracy: 0.9766 - f1_score: 0.9766 - loss: 0.2089 - val_accuracy: 0.9469 - val_f1_score: 0.9463 - val_loss: 0.2184
# Epoch 133/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9779 - f1_score: 0.9779 - loss: 0.2050 - val_accuracy: 0.9364 - val_f1_score: 0.9360 - val_loss: 0.2368
# Epoch 134/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.9776 - f1_score: 0.9775 - loss: 0.2058 - val_accuracy: 0.9488 - val_f1_score: 0.9485 - val_loss: 0.2106
# Epoch 135/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.9754 - f1_score: 0.9754 - loss: 0.2057 - val_accuracy: 0.9471 - val_f1_score: 0.9469 - val_loss: 0.2096
# Epoch 136/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9789 - f1_score: 0.9789 - loss: 0.2002 - val_accuracy: 0.9550 - val_f1_score: 0.9547 - val_loss: 0.1987
# Epoch 137/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.9775 - f1_score: 0.9775 - loss: 0.1997 - val_accuracy: 0.9421 - val_f1_score: 0.9418 - val_loss: 0.2230
# Epoch 138/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 91s 90ms/step - accuracy: 0.9778 - f1_score: 0.9777 - loss: 0.2003 - val_accuracy: 0.9412 - val_f1_score: 0.9410 - val_loss: 0.2207
# Epoch 139/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 91s 90ms/step - accuracy: 0.9776 - f1_score: 0.9776 - loss: 0.1954 - val_accuracy: 0.9332 - val_f1_score: 0.9331 - val_loss: 0.2417
# Epoch 140/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9791 - f1_score: 0.9790 - loss: 0.1919 - val_accuracy: 0.9502 - val_f1_score: 0.9498 - val_loss: 0.2034
# Epoch 141/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9780 - f1_score: 0.9780 - loss: 0.1931 - val_accuracy: 0.9361 - val_f1_score: 0.9356 - val_loss: 0.2280
# Epoch 142/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9801 - f1_score: 0.9801 - loss: 0.1892 - val_accuracy: 0.9533 - val_f1_score: 0.9530 - val_loss: 0.1947
# Epoch 143/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9790 - f1_score: 0.9790 - loss: 0.1909 - val_accuracy: 0.9437 - val_f1_score: 0.9432 - val_loss: 0.2159
# Epoch 144/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9786 - f1_score: 0.9786 - loss: 0.1883 - val_accuracy: 0.9571 - val_f1_score: 0.9568 - val_loss: 0.1862
# Epoch 145/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.9809 - f1_score: 0.9809 - loss: 0.1847 - val_accuracy: 0.9459 - val_f1_score: 0.9456 - val_loss: 0.2064
# Epoch 146/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9788 - f1_score: 0.9788 - loss: 0.1878 - val_accuracy: 0.9475 - val_f1_score: 0.9473 - val_loss: 0.2140
# Epoch 147/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9791 - f1_score: 0.9791 - loss: 0.1820 - val_accuracy: 0.9351 - val_f1_score: 0.9347 - val_loss: 0.2328
# Epoch 148/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9809 - f1_score: 0.9809 - loss: 0.1783 - val_accuracy: 0.9451 - val_f1_score: 0.9446 - val_loss: 0.2056
# Epoch 149/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.9809 - f1_score: 0.9808 - loss: 0.1779 - val_accuracy: 0.9510 - val_f1_score: 0.9508 - val_loss: 0.2066
# Epoch 150/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9786 - f1_score: 0.9785 - loss: 0.1821 - val_accuracy: 0.9394 - val_f1_score: 0.9389 - val_loss: 0.2198
# Restoring model weights from the end of the best epoch: 144.

# %%
model.save('/content/drive/MyDrive/Universidad/Investigacion/models/codet5_2.keras')

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
train_f1 = history.history['f1_score']
val_f1 = history.history['val_f1_score']

# %%
length = len(history.history['accuracy'])

# %%
import matplotlib.pyplot as plt

plt.plot(range(1, length+1), train_loss, label='Train Loss')
plt.plot(range(1, length+1), val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curves')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(range(1, length+1), train_f1, label='Train F1')
plt.plot(range(1, length+1), val_f1, label='Validation F1')
plt.xlabel('Epoch')
plt.ylabel('F1')
plt.title('F1 Curves')
plt.legend()
plt.show()
