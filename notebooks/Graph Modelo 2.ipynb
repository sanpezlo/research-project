# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers
# !pip install -U gensim
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.4.4)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.0.0)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 97.6 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
import tensorflow as tf
import numpy as np
import random
import os

SEED = 2025

os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
tf.config.experimental.enable_op_determinism()

# %%
import tensorflow as tf

print("GPU available:", tf.config.list_physical_devices('GPU'))

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        print(e)
# Out:
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 1 Physical GPUs, 1 Logical GPUs

# %%
import tensorflow as tf

dataset_train = tf.data.Dataset.load("/content/drive/MyDrive/Universidad/Investigacion/tf_datasets_2/train")

# %%
from tensorflow.keras.layers import Dense, Input, Dropout, Bidirectional, LSTM, Embedding, BatchNormalization, Reshape, Conv2D, MaxPool2D, concatenate, Flatten
from tensorflow.keras.layers import Conv1D, GlobalMaxPooling1D, MaxPooling1D, Input, Bidirectional, GRU, Flatten, concatenate, BatchNormalization, Dense, LeakyReLU, Activation
from tensorflow.keras.models import Model
from keras import regularizers

num_classes = 8

def create_input_branch(input_shape, name):
    input_layer = Input(shape=input_shape, name=name)
    dense1 = Dense(10000)(input_layer)
    batch1 = BatchNormalization()(dense1)
    activation1 = Activation('relu')(batch1)
    drop1 = Dropout(0.2)(activation1)

    dense2 = Dense(1000)(drop1)
    batch2 = BatchNormalization()(dense2)
    activation2 = Activation('relu')(batch2)
    drop2 = Dropout(0.2)(activation2)

    dense3 = Dense(100)(drop2)
    batch3 = BatchNormalization()(dense3)
    activation3 = Activation('relu')(batch3)
    drop3 = Dropout(0.2)(activation3)

    dense4 = Dense(10)(drop3)
    batch4 = BatchNormalization()(dense4)
    activation4 = Activation('relu')(batch4)
    drop4 = Dropout(0.2)(activation4)
    return input_layer, drop4

input_nl, output_nl = create_input_branch((768,), "nl")
input_pl, output_pl = create_input_branch((768,), "pl")
input_initial, output_initial = create_input_branch((768,), "initial")
input_transformation, output_transformation = create_input_branch((768,), "transformation")
input_js, output_js = create_input_branch((768,), "js")
input_final, output_final = create_input_branch((768,), "final")


concat = concatenate([output_nl, output_pl, output_initial, output_transformation, output_js, output_final])

output = Dense(num_classes)(concat)
output = BatchNormalization()(output)
output = Activation('softmax')(output)

model = Model(inputs=[input_nl, input_pl, input_initial, input_transformation, input_js, input_final], outputs=output)

# %%
# %%time
from tensorflow.keras.optimizers import Adam
adam = Adam(learning_rate=0.00001)

model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy', tf.keras.metrics.F1Score(average='macro')])

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ nl (InputLayer)     │ (None, 768)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pl (InputLayer)     │ (None, 768)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ initial             │ (None, 768)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformation      │ (None, 768)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ js (InputLayer)     │ (None, 768)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final (InputLayer)  │ (None, 768)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 10000)     │  7,690,000 │ nl[0][0]          │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 10000)     │  7,690,000 │ pl[0][0]          │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 10000)     │  7,690,000 │ initial[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 10000)     │  7,690,000 │ transformation[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 10000)     │  7,690,000 │ js[0][0]          │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 10000)     │  7,690,000 │ final[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 10000)     │     40,000 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_4[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_8[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_12[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_16[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10000)     │     40,000 │ dense_20[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 10000)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 10000)     │          0 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 10000)     │          0 │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 10000)     │          0 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 10000)     │          0 │ activation_12[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 10000)     │          0 │ activation_16[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 10000)     │          0 │ activation_20[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1000)      │ 10,001,000 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 1000)      │ 10,001,000 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 1000)      │ 10,001,000 │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 1000)      │ 10,001,000 │ dropout_12[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 1000)      │ 10,001,000 │ dropout_16[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_21 (Dense)    │ (None, 1000)      │ 10,001,000 │ dropout_20[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1000)      │      4,000 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1000)      │      4,000 │ dense_5[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1000)      │      4,000 │ dense_9[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1000)      │      4,000 │ dense_13[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1000)      │      4,000 │ dense_17[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1000)      │      4,000 │ dense_21[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 1000)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 1000)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 1000)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 1000)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 1000)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 1000)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 1000)      │          0 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 1000)      │          0 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 1000)      │          0 │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 1000)      │          0 │ activation_13[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 1000)      │          0 │ activation_17[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_21          │ (None, 1000)      │          0 │ activation_21[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 100)       │    100,100 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 100)       │    100,100 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 100)       │    100,100 │ dropout_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 100)       │    100,100 │ dropout_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 100)       │    100,100 │ dropout_17[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_22 (Dense)    │ (None, 100)       │    100,100 │ dropout_21[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100)       │        400 │ dense_2[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100)       │        400 │ dense_6[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100)       │        400 │ dense_10[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100)       │        400 │ dense_14[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100)       │        400 │ dense_18[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100)       │        400 │ dense_22[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 100)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 100)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 100)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 100)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 100)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 100)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 100)       │          0 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 100)       │          0 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 100)       │          0 │ activation_10[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 100)       │          0 │ activation_14[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_18          │ (None, 100)       │          0 │ activation_18[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 100)       │          0 │ activation_22[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 10)        │      1,010 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 10)        │      1,010 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 10)        │      1,010 │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 10)        │      1,010 │ dropout_14[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 10)        │      1,010 │ dropout_18[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_23 (Dense)    │ (None, 10)        │      1,010 │ dropout_22[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10)        │         40 │ dense_3[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10)        │         40 │ dense_7[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10)        │         40 │ dense_11[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10)        │         40 │ dense_15[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10)        │         40 │ dense_19[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10)        │         40 │ dense_23[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 10)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 10)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 10)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 10)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 10)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 10)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 10)        │          0 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 10)        │          0 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 10)        │          0 │ activation_11[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, 10)        │          0 │ activation_15[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 10)        │          0 │ activation_19[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 10)        │          0 │ activation_23[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 60)        │          0 │ dropout_3[0][0],  │
# │ (Concatenate)       │                   │            │ dropout_7[0][0],  │
# │                     │                   │            │ dropout_11[0][0], │
# │                     │                   │            │ dropout_15[0][0], │
# │                     │                   │            │ dropout_19[0][0], │
# │                     │                   │            │ dropout_23[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_24 (Dense)    │ (None, 8)         │        488 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8)         │         32 │ dense_24[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 8)         │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 107,019,820 (408.25 MB)
#  Trainable params: 106,886,484 (407.74 MB)
#  Non-trainable params: 133,336 (520.84 KB)
# CPU times: user 101 ms, sys: 891 µs, total: 102 ms
# Wall time: 103 ms

# %%
from tensorflow.keras.callbacks import EarlyStopping

total_size = dataset_train.reduce(0, lambda x, _: x + 1).numpy()
val_size = int(0.2 * total_size)

dataset_train = dataset_train.shuffle(
    buffer_size=total_size,
    seed=SEED,
    reshuffle_each_iteration=False
)

val_dataset = dataset_train.take(val_size)
train_dataset = dataset_train.skip(val_size)



epochs=150

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)


history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=epochs,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 111s 92ms/step - accuracy: 0.2267 - f1_score: 0.2255 - loss: 2.0393 - val_accuracy: 0.4552 - val_f1_score: 0.4464 - val_loss: 1.5601
# Epoch 2/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.3520 - f1_score: 0.3498 - loss: 1.6898 - val_accuracy: 0.5568 - val_f1_score: 0.5495 - val_loss: 1.3947
# Epoch 3/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.4248 - f1_score: 0.4216 - loss: 1.5516 - val_accuracy: 0.6132 - val_f1_score: 0.6078 - val_loss: 1.2977
# Epoch 4/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.4765 - f1_score: 0.4738 - loss: 1.4524 - val_accuracy: 0.6761 - val_f1_score: 0.6686 - val_loss: 1.2216
# Epoch 5/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.5211 - f1_score: 0.5183 - loss: 1.3802 - val_accuracy: 0.7237 - val_f1_score: 0.7164 - val_loss: 1.1545
# Epoch 6/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.5608 - f1_score: 0.5577 - loss: 1.3217 - val_accuracy: 0.7581 - val_f1_score: 0.7503 - val_loss: 1.1062
# Epoch 7/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.5945 - f1_score: 0.5914 - loss: 1.2648 - val_accuracy: 0.7801 - val_f1_score: 0.7736 - val_loss: 1.0652
# Epoch 8/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.6295 - f1_score: 0.6268 - loss: 1.2185 - val_accuracy: 0.7968 - val_f1_score: 0.7909 - val_loss: 1.0378
# Epoch 9/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.6588 - f1_score: 0.6562 - loss: 1.1723 - val_accuracy: 0.8162 - val_f1_score: 0.8116 - val_loss: 0.9904
# Epoch 10/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.6799 - f1_score: 0.6773 - loss: 1.1369 - val_accuracy: 0.8332 - val_f1_score: 0.8289 - val_loss: 0.9591
# Epoch 11/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 91s 90ms/step - accuracy: 0.7029 - f1_score: 0.7009 - loss: 1.0994 - val_accuracy: 0.8545 - val_f1_score: 0.8522 - val_loss: 0.9207
# Epoch 12/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.7156 - f1_score: 0.7136 - loss: 1.0753 - val_accuracy: 0.8560 - val_f1_score: 0.8541 - val_loss: 0.8983
# Epoch 13/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.7374 - f1_score: 0.7358 - loss: 1.0428 - val_accuracy: 0.8618 - val_f1_score: 0.8595 - val_loss: 0.8737
# Epoch 14/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 91ms/step - accuracy: 0.7534 - f1_score: 0.7520 - loss: 1.0149 - val_accuracy: 0.8655 - val_f1_score: 0.8636 - val_loss: 0.8540
# Epoch 15/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.7707 - f1_score: 0.7692 - loss: 0.9840 - val_accuracy: 0.8759 - val_f1_score: 0.8742 - val_loss: 0.8353
# Epoch 16/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 91s 90ms/step - accuracy: 0.7738 - f1_score: 0.7727 - loss: 0.9675 - val_accuracy: 0.8866 - val_f1_score: 0.8856 - val_loss: 0.8036
# Epoch 17/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.7904 - f1_score: 0.7895 - loss: 0.9427 - val_accuracy: 0.8861 - val_f1_score: 0.8848 - val_loss: 0.7820
# Epoch 18/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8040 - f1_score: 0.8031 - loss: 0.9215 - val_accuracy: 0.8980 - val_f1_score: 0.8974 - val_loss: 0.7637
# Epoch 19/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8079 - f1_score: 0.8070 - loss: 0.9046 - val_accuracy: 0.8955 - val_f1_score: 0.8944 - val_loss: 0.7379
# Epoch 20/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8211 - f1_score: 0.8204 - loss: 0.8847 - val_accuracy: 0.9084 - val_f1_score: 0.9078 - val_loss: 0.7426
# Epoch 21/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8245 - f1_score: 0.8238 - loss: 0.8709 - val_accuracy: 0.9064 - val_f1_score: 0.9059 - val_loss: 0.7095
# Epoch 22/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 91s 90ms/step - accuracy: 0.8307 - f1_score: 0.8301 - loss: 0.8508 - val_accuracy: 0.9065 - val_f1_score: 0.9058 - val_loss: 0.7088
# Epoch 23/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8390 - f1_score: 0.8386 - loss: 0.8334 - val_accuracy: 0.9156 - val_f1_score: 0.9151 - val_loss: 0.7065
# Epoch 24/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8450 - f1_score: 0.8446 - loss: 0.8162 - val_accuracy: 0.9146 - val_f1_score: 0.9139 - val_loss: 0.6819
# Epoch 25/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8498 - f1_score: 0.8495 - loss: 0.8028 - val_accuracy: 0.9180 - val_f1_score: 0.9176 - val_loss: 0.6833
# Epoch 26/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8511 - f1_score: 0.8509 - loss: 0.7930 - val_accuracy: 0.9113 - val_f1_score: 0.9106 - val_loss: 0.6604
# Epoch 27/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8604 - f1_score: 0.8600 - loss: 0.7752 - val_accuracy: 0.9166 - val_f1_score: 0.9161 - val_loss: 0.6459
# Epoch 28/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8596 - f1_score: 0.8593 - loss: 0.7630 - val_accuracy: 0.9195 - val_f1_score: 0.9191 - val_loss: 0.6484
# Epoch 29/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8627 - f1_score: 0.8624 - loss: 0.7466 - val_accuracy: 0.9188 - val_f1_score: 0.9184 - val_loss: 0.6122
# Epoch 30/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 91s 90ms/step - accuracy: 0.8710 - f1_score: 0.8706 - loss: 0.7349 - val_accuracy: 0.9165 - val_f1_score: 0.9160 - val_loss: 0.5932
# Epoch 31/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8713 - f1_score: 0.8710 - loss: 0.7213 - val_accuracy: 0.9173 - val_f1_score: 0.9169 - val_loss: 0.5810
# Epoch 32/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8780 - f1_score: 0.8777 - loss: 0.7109 - val_accuracy: 0.9230 - val_f1_score: 0.9225 - val_loss: 0.5658
# Epoch 33/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 91s 90ms/step - accuracy: 0.8814 - f1_score: 0.8812 - loss: 0.6965 - val_accuracy: 0.9327 - val_f1_score: 0.9323 - val_loss: 0.5646
# Epoch 34/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 91s 90ms/step - accuracy: 0.8827 - f1_score: 0.8824 - loss: 0.6862 - val_accuracy: 0.9322 - val_f1_score: 0.9320 - val_loss: 0.5576
# Epoch 35/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 91s 90ms/step - accuracy: 0.8841 - f1_score: 0.8840 - loss: 0.6751 - val_accuracy: 0.9251 - val_f1_score: 0.9246 - val_loss: 0.5395
# Epoch 36/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8883 - f1_score: 0.8882 - loss: 0.6636 - val_accuracy: 0.9290 - val_f1_score: 0.9287 - val_loss: 0.5564
# Epoch 37/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8948 - f1_score: 0.8946 - loss: 0.6477 - val_accuracy: 0.9336 - val_f1_score: 0.9332 - val_loss: 0.5310
# Epoch 38/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8941 - f1_score: 0.8940 - loss: 0.6366 - val_accuracy: 0.9404 - val_f1_score: 0.9402 - val_loss: 0.5219
# Epoch 39/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8941 - f1_score: 0.8940 - loss: 0.6294 - val_accuracy: 0.9351 - val_f1_score: 0.9348 - val_loss: 0.4972
# Epoch 40/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8974 - f1_score: 0.8972 - loss: 0.6225 - val_accuracy: 0.9361 - val_f1_score: 0.9360 - val_loss: 0.4987
# Epoch 41/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.8985 - f1_score: 0.8984 - loss: 0.6111 - val_accuracy: 0.9366 - val_f1_score: 0.9364 - val_loss: 0.5066
# Epoch 42/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9005 - f1_score: 0.9004 - loss: 0.6034 - val_accuracy: 0.9418 - val_f1_score: 0.9417 - val_loss: 0.5218
# Epoch 43/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9063 - f1_score: 0.9062 - loss: 0.5879 - val_accuracy: 0.9362 - val_f1_score: 0.9361 - val_loss: 0.5381
# Epoch 44/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9060 - f1_score: 0.9060 - loss: 0.5862 - val_accuracy: 0.9361 - val_f1_score: 0.9359 - val_loss: 0.4698
# Epoch 45/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9033 - f1_score: 0.9033 - loss: 0.5778 - val_accuracy: 0.9329 - val_f1_score: 0.9327 - val_loss: 0.5202
# Epoch 46/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9097 - f1_score: 0.9096 - loss: 0.5654 - val_accuracy: 0.9388 - val_f1_score: 0.9385 - val_loss: 0.4774
# Epoch 47/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9074 - f1_score: 0.9073 - loss: 0.5577 - val_accuracy: 0.9371 - val_f1_score: 0.9368 - val_loss: 0.4606
# Epoch 48/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9149 - f1_score: 0.9148 - loss: 0.5466 - val_accuracy: 0.9417 - val_f1_score: 0.9414 - val_loss: 0.4780
# Epoch 49/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9150 - f1_score: 0.9149 - loss: 0.5434 - val_accuracy: 0.9370 - val_f1_score: 0.9369 - val_loss: 0.4666
# Epoch 50/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9151 - f1_score: 0.9151 - loss: 0.5347 - val_accuracy: 0.9369 - val_f1_score: 0.9366 - val_loss: 0.4733
# Epoch 51/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9156 - f1_score: 0.9155 - loss: 0.5309 - val_accuracy: 0.9400 - val_f1_score: 0.9398 - val_loss: 0.4341
# Epoch 52/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9178 - f1_score: 0.9177 - loss: 0.5199 - val_accuracy: 0.9342 - val_f1_score: 0.9340 - val_loss: 0.4276
# Epoch 53/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9196 - f1_score: 0.9195 - loss: 0.5138 - val_accuracy: 0.9409 - val_f1_score: 0.9407 - val_loss: 0.4191
# Epoch 54/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9205 - f1_score: 0.9205 - loss: 0.5063 - val_accuracy: 0.9464 - val_f1_score: 0.9462 - val_loss: 0.4214
# Epoch 55/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9235 - f1_score: 0.9234 - loss: 0.4961 - val_accuracy: 0.9380 - val_f1_score: 0.9378 - val_loss: 0.4218
# Epoch 56/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9224 - f1_score: 0.9223 - loss: 0.4936 - val_accuracy: 0.9280 - val_f1_score: 0.9278 - val_loss: 0.4052
# Epoch 57/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9256 - f1_score: 0.9256 - loss: 0.4860 - val_accuracy: 0.9434 - val_f1_score: 0.9433 - val_loss: 0.4182
# Epoch 58/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9250 - f1_score: 0.9249 - loss: 0.4796 - val_accuracy: 0.9353 - val_f1_score: 0.9351 - val_loss: 0.3862
# Epoch 59/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9288 - f1_score: 0.9288 - loss: 0.4719 - val_accuracy: 0.9310 - val_f1_score: 0.9311 - val_loss: 0.4576
# Epoch 60/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9310 - f1_score: 0.9310 - loss: 0.4647 - val_accuracy: 0.9464 - val_f1_score: 0.9462 - val_loss: 0.3863
# Epoch 61/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9297 - f1_score: 0.9297 - loss: 0.4643 - val_accuracy: 0.9455 - val_f1_score: 0.9452 - val_loss: 0.3760
# Epoch 62/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.9277 - f1_score: 0.9277 - loss: 0.4602 - val_accuracy: 0.9438 - val_f1_score: 0.9436 - val_loss: 0.4049
# Epoch 63/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9330 - f1_score: 0.9329 - loss: 0.4484 - val_accuracy: 0.9408 - val_f1_score: 0.9406 - val_loss: 0.3671
# Epoch 64/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.9371 - f1_score: 0.9371 - loss: 0.4403 - val_accuracy: 0.9472 - val_f1_score: 0.9471 - val_loss: 0.3883
# Epoch 65/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9347 - f1_score: 0.9347 - loss: 0.4389 - val_accuracy: 0.9467 - val_f1_score: 0.9466 - val_loss: 0.3742
# Epoch 66/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9363 - f1_score: 0.9363 - loss: 0.4334 - val_accuracy: 0.9340 - val_f1_score: 0.9339 - val_loss: 0.4082
# Epoch 67/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 90ms/step - accuracy: 0.9356 - f1_score: 0.9356 - loss: 0.4297 - val_accuracy: 0.9499 - val_f1_score: 0.9498 - val_loss: 0.3509
# Epoch 68/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9355 - f1_score: 0.9355 - loss: 0.4248 - val_accuracy: 0.9372 - val_f1_score: 0.9370 - val_loss: 0.3481
# Epoch 69/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9415 - f1_score: 0.9415 - loss: 0.4147 - val_accuracy: 0.9461 - val_f1_score: 0.9460 - val_loss: 0.3525
# Epoch 70/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9379 - f1_score: 0.9378 - loss: 0.4111 - val_accuracy: 0.9440 - val_f1_score: 0.9438 - val_loss: 0.3599
# Epoch 71/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9433 - f1_score: 0.9433 - loss: 0.4057 - val_accuracy: 0.9505 - val_f1_score: 0.9504 - val_loss: 0.3679
# Epoch 72/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9437 - f1_score: 0.9437 - loss: 0.3996 - val_accuracy: 0.9498 - val_f1_score: 0.9497 - val_loss: 0.3396
# Epoch 73/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9444 - f1_score: 0.9443 - loss: 0.3967 - val_accuracy: 0.9531 - val_f1_score: 0.9529 - val_loss: 0.3352
# Epoch 74/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9442 - f1_score: 0.9442 - loss: 0.3937 - val_accuracy: 0.9403 - val_f1_score: 0.9401 - val_loss: 0.3684
# Epoch 75/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9429 - f1_score: 0.9429 - loss: 0.3901 - val_accuracy: 0.9465 - val_f1_score: 0.9463 - val_loss: 0.3614
# Epoch 76/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.9448 - f1_score: 0.9447 - loss: 0.3836 - val_accuracy: 0.9294 - val_f1_score: 0.9293 - val_loss: 0.3531
# Epoch 77/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9485 - f1_score: 0.9484 - loss: 0.3783 - val_accuracy: 0.9385 - val_f1_score: 0.9384 - val_loss: 0.3284
# Epoch 78/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9481 - f1_score: 0.9481 - loss: 0.3746 - val_accuracy: 0.9288 - val_f1_score: 0.9283 - val_loss: 0.3193
# Epoch 79/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.9488 - f1_score: 0.9488 - loss: 0.3713 - val_accuracy: 0.9499 - val_f1_score: 0.9498 - val_loss: 0.3296
# Epoch 80/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.9515 - f1_score: 0.9515 - loss: 0.3626 - val_accuracy: 0.9465 - val_f1_score: 0.9463 - val_loss: 0.3496
# Epoch 81/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.9502 - f1_score: 0.9502 - loss: 0.3620 - val_accuracy: 0.9390 - val_f1_score: 0.9388 - val_loss: 0.3316
# Epoch 82/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.9511 - f1_score: 0.9510 - loss: 0.3585 - val_accuracy: 0.9364 - val_f1_score: 0.9361 - val_loss: 0.3619
# Epoch 83/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.9528 - f1_score: 0.9528 - loss: 0.3545 - val_accuracy: 0.9431 - val_f1_score: 0.9428 - val_loss: 0.3460
# Epoch 84/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.9542 - f1_score: 0.9542 - loss: 0.3480 - val_accuracy: 0.9437 - val_f1_score: 0.9436 - val_loss: 0.3347
# Epoch 85/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9530 - f1_score: 0.9530 - loss: 0.3447 - val_accuracy: 0.9456 - val_f1_score: 0.9454 - val_loss: 0.3167
# Epoch 86/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9517 - f1_score: 0.9517 - loss: 0.3428 - val_accuracy: 0.9452 - val_f1_score: 0.9450 - val_loss: 0.2907
# Epoch 87/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.9558 - f1_score: 0.9558 - loss: 0.3358 - val_accuracy: 0.9481 - val_f1_score: 0.9480 - val_loss: 0.2945
# Epoch 88/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.9582 - f1_score: 0.9582 - loss: 0.3322 - val_accuracy: 0.9452 - val_f1_score: 0.9450 - val_loss: 0.3360
# Epoch 89/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.9543 - f1_score: 0.9543 - loss: 0.3277 - val_accuracy: 0.9489 - val_f1_score: 0.9488 - val_loss: 0.2835
# Epoch 90/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.9560 - f1_score: 0.9560 - loss: 0.3271 - val_accuracy: 0.9250 - val_f1_score: 0.9244 - val_loss: 0.2962
# Epoch 91/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.9590 - f1_score: 0.9590 - loss: 0.3212 - val_accuracy: 0.9499 - val_f1_score: 0.9497 - val_loss: 0.2814
# Epoch 92/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.9604 - f1_score: 0.9604 - loss: 0.3182 - val_accuracy: 0.9422 - val_f1_score: 0.9420 - val_loss: 0.3147
# Epoch 93/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9582 - f1_score: 0.9582 - loss: 0.3162 - val_accuracy: 0.9505 - val_f1_score: 0.9503 - val_loss: 0.2732
# Epoch 94/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.9594 - f1_score: 0.9594 - loss: 0.3145 - val_accuracy: 0.9299 - val_f1_score: 0.9295 - val_loss: 0.3336
# Epoch 95/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.9587 - f1_score: 0.9587 - loss: 0.3124 - val_accuracy: 0.9423 - val_f1_score: 0.9424 - val_loss: 0.2881
# Epoch 96/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.9610 - f1_score: 0.9610 - loss: 0.3066 - val_accuracy: 0.9461 - val_f1_score: 0.9461 - val_loss: 0.3154
# Epoch 97/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9607 - f1_score: 0.9607 - loss: 0.3002 - val_accuracy: 0.9494 - val_f1_score: 0.9493 - val_loss: 0.2791
# Epoch 98/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9615 - f1_score: 0.9615 - loss: 0.2992 - val_accuracy: 0.9386 - val_f1_score: 0.9384 - val_loss: 0.3050
# Epoch 99/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9626 - f1_score: 0.9626 - loss: 0.2936 - val_accuracy: 0.9476 - val_f1_score: 0.9476 - val_loss: 0.2598
# Epoch 100/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 91s 91ms/step - accuracy: 0.9609 - f1_score: 0.9610 - loss: 0.2962 - val_accuracy: 0.9529 - val_f1_score: 0.9528 - val_loss: 0.2551
# Epoch 101/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 91s 90ms/step - accuracy: 0.9621 - f1_score: 0.9621 - loss: 0.2924 - val_accuracy: 0.9532 - val_f1_score: 0.9531 - val_loss: 0.2652
# Epoch 102/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9645 - f1_score: 0.9645 - loss: 0.2844 - val_accuracy: 0.9470 - val_f1_score: 0.9469 - val_loss: 0.2985
# Epoch 103/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9662 - f1_score: 0.9662 - loss: 0.2827 - val_accuracy: 0.9356 - val_f1_score: 0.9354 - val_loss: 0.2764
# Epoch 104/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9656 - f1_score: 0.9656 - loss: 0.2800 - val_accuracy: 0.9197 - val_f1_score: 0.9192 - val_loss: 0.2965
# Epoch 105/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 91s 91ms/step - accuracy: 0.9643 - f1_score: 0.9643 - loss: 0.2790 - val_accuracy: 0.9460 - val_f1_score: 0.9459 - val_loss: 0.2600
# Epoch 106/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 91s 90ms/step - accuracy: 0.9641 - f1_score: 0.9641 - loss: 0.2753 - val_accuracy: 0.9407 - val_f1_score: 0.9405 - val_loss: 0.2862
# Epoch 107/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9668 - f1_score: 0.9668 - loss: 0.2691 - val_accuracy: 0.9576 - val_f1_score: 0.9575 - val_loss: 0.2487
# Epoch 108/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9678 - f1_score: 0.9678 - loss: 0.2693 - val_accuracy: 0.9518 - val_f1_score: 0.9517 - val_loss: 0.2455
# Epoch 109/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9684 - f1_score: 0.9684 - loss: 0.2642 - val_accuracy: 0.9507 - val_f1_score: 0.9505 - val_loss: 0.2515
# Epoch 110/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.9680 - f1_score: 0.9679 - loss: 0.2654 - val_accuracy: 0.9520 - val_f1_score: 0.9520 - val_loss: 0.2507
# Epoch 111/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9669 - f1_score: 0.9669 - loss: 0.2607 - val_accuracy: 0.9415 - val_f1_score: 0.9415 - val_loss: 0.2569
# Epoch 112/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9686 - f1_score: 0.9686 - loss: 0.2590 - val_accuracy: 0.9280 - val_f1_score: 0.9278 - val_loss: 0.3169
# Epoch 113/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.9715 - f1_score: 0.9715 - loss: 0.2526 - val_accuracy: 0.8974 - val_f1_score: 0.8970 - val_loss: 0.3548
# Epoch 114/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9682 - f1_score: 0.9682 - loss: 0.2548 - val_accuracy: 0.9493 - val_f1_score: 0.9492 - val_loss: 0.2541
# Epoch 115/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.9676 - f1_score: 0.9676 - loss: 0.2524 - val_accuracy: 0.9499 - val_f1_score: 0.9499 - val_loss: 0.2484
# Epoch 116/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9708 - f1_score: 0.9708 - loss: 0.2474 - val_accuracy: 0.9494 - val_f1_score: 0.9492 - val_loss: 0.2439
# Epoch 117/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.9736 - f1_score: 0.9736 - loss: 0.2400 - val_accuracy: 0.9141 - val_f1_score: 0.9135 - val_loss: 0.3115
# Epoch 118/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.9701 - f1_score: 0.9701 - loss: 0.2429 - val_accuracy: 0.9246 - val_f1_score: 0.9244 - val_loss: 0.3262
# Epoch 119/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9733 - f1_score: 0.9733 - loss: 0.2369 - val_accuracy: 0.9494 - val_f1_score: 0.9493 - val_loss: 0.2437
# Epoch 120/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9725 - f1_score: 0.9725 - loss: 0.2372 - val_accuracy: 0.9419 - val_f1_score: 0.9417 - val_loss: 0.2432
# Epoch 121/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9728 - f1_score: 0.9728 - loss: 0.2349 - val_accuracy: 0.9509 - val_f1_score: 0.9508 - val_loss: 0.2432
# Epoch 122/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9723 - f1_score: 0.9723 - loss: 0.2338 - val_accuracy: 0.9400 - val_f1_score: 0.9398 - val_loss: 0.2515
# Epoch 123/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.9757 - f1_score: 0.9757 - loss: 0.2272 - val_accuracy: 0.9502 - val_f1_score: 0.9500 - val_loss: 0.2255
# Epoch 124/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.9739 - f1_score: 0.9739 - loss: 0.2276 - val_accuracy: 0.9512 - val_f1_score: 0.9510 - val_loss: 0.2374
# Epoch 125/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9746 - f1_score: 0.9746 - loss: 0.2283 - val_accuracy: 0.9378 - val_f1_score: 0.9378 - val_loss: 0.2422
# Epoch 126/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.9739 - f1_score: 0.9739 - loss: 0.2232 - val_accuracy: 0.9413 - val_f1_score: 0.9412 - val_loss: 0.2679
# Epoch 127/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.9720 - f1_score: 0.9720 - loss: 0.2232 - val_accuracy: 0.9385 - val_f1_score: 0.9385 - val_loss: 0.2663
# Epoch 128/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.9759 - f1_score: 0.9759 - loss: 0.2182 - val_accuracy: 0.9464 - val_f1_score: 0.9461 - val_loss: 0.2532
# Epoch 129/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 89s 89ms/step - accuracy: 0.9740 - f1_score: 0.9740 - loss: 0.2202 - val_accuracy: 0.9407 - val_f1_score: 0.9407 - val_loss: 0.2335
# Epoch 130/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9750 - f1_score: 0.9750 - loss: 0.2173 - val_accuracy: 0.9403 - val_f1_score: 0.9402 - val_loss: 0.2416
# Epoch 131/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9774 - f1_score: 0.9774 - loss: 0.2103 - val_accuracy: 0.9495 - val_f1_score: 0.9494 - val_loss: 0.2269
# Epoch 132/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 90ms/step - accuracy: 0.9747 - f1_score: 0.9747 - loss: 0.2124 - val_accuracy: 0.9452 - val_f1_score: 0.9450 - val_loss: 0.2391
# Epoch 133/150
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 90s 89ms/step - accuracy: 0.9761 - f1_score: 0.9761 - loss: 0.2070 - val_accuracy: 0.9428 - val_f1_score: 0.9428 - val_loss: 0.2572
# Epoch 133: early stopping
# Restoring model weights from the end of the best epoch: 123.

# %%
model.save('/content/drive/MyDrive/Universidad/Investigacion/models/graph_2.keras')

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
train_f1 = history.history['f1_score']
val_f1 = history.history['val_f1_score']

# %%
length = len(history.history['accuracy'])

# %%
import matplotlib.pyplot as plt

plt.plot(range(1, length+1), train_loss, label='Train Loss')
plt.plot(range(1, length+1), val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curves')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(range(1, length+1), train_f1, label='Train F1')
plt.plot(range(1, length+1), val_f1, label='Validation F1')
plt.xlabel('Epoch')
plt.ylabel('F1')
plt.title('F1 Curves')
plt.legend()
plt.show()
